# %% [markdown]
# # Example usage
#
# To use `unesco_reader` in a project:

# %%
import unesco_reader

print(unesco_reader.__version__)
# Out:
# 0.1.2

# %% [markdown]
# To explore UIS data import the `uis` module fomr `unesco_reader`

# %%
from unesco_reader import uis

# %% [markdown]
# Explore the available datasets and get information about a particular dataset

# %%
uis.available_datasets() # see available datasets - returns a list of dataset codes
# Out:
# ['SDG', 'OPRI', 'SCI', 'SDG11', 'DEM']

# %%
uis.available_datasets(as_names=True) # get the full names for available datasets
# Out:
# ['SDG Global and Thematic Indicators',
#  'Other Policy Relevant Indicators',
#  'Research and Development (R&D) SDG 9.5',
#  'SDG 11.4',
#  'Demographic and Socio-economic Indicators']

# %%
uis.available_datasets(category='education')
# Out:
# ['SDG', 'OPRI']

# %%
uis.dataset_info('SDG') #get information about the SDG dataset
# Out:
# ----------------  ----------------------------------------------------------------------------------------
# dataset_name      SDG Global and Thematic Indicators
# dataset_code      SDG
# dataset_category  education
# regional          True
# link              https://apimgmtstzgjpfeq2u763lag.blob.core.windows.net/content/MediaLibrary/bdds/SDG.zip
# ----------------  ----------------------------------------------------------------------------------------

# %% [markdown]
# To access and explore the data for a particular UIS dataset, use the `UIS` object

# %%
# First, instantiate a `UIS` object, passing the dataset code or name that you want to explore
# Here we are going to instantiate the `SDG` dataset

sdg = uis.UIS('SDG') # you can also pass the dataset name `SDG Global and Thematic Indicators`
sdg

# %% [markdown]
# You can get information about the dataset, such as dataset name, code, category, and link to download the data zipped file

# %%
sdg.dataset_code
# Out:
# 'SDG'

# %%
sdg.dataset_name
# Out:
# 'SDG Global and Thematic Indicators'

# %%
sdg.dataset_category
# Out:
# 'education'

# %%
sdg.link
# Out:
# 'https://apimgmtstzgjpfeq2u763lag.blob.core.windows.net/content/MediaLibrary/bdds/SDG.zip'

# %% [markdown]
# In order to explore the data, use the `load_data` which loads data to the object by downloading it from
# UNESCO, cleaning it, and formatting it to a pandas DataFrame.
#
# If you already downloaded the zipped file locally,
# you can pass the path to the file, and the data will be read from the local file rather than being downloaded.

# %%
sdg.load_data() # optionally pass `local_path = "path to zipped file..."` to use a locally downloaded file
# Out:
# INFO 2023-01-26 12:47:03,895 [uis.py:load_data:285] Data loaded for dataset: SDG

# %% [markdown]
# Now that the data is loaded to the object you can start exploring it!

# %% [markdown]
# To get general information about the dataset use the `info()` methos

# %%
sdg.info()
# Out:
# --------------------  ----------------------------------------------------------------------------------------
# dataset_name          SDG Global and Thematic Indicators
# dataset_code          SDG
# dataset_category      education
# regional              True
# link                  https://apimgmtstzgjpfeq2u763lag.blob.core.windows.net/content/MediaLibrary/bdds/SDG.zip
# available indicators  1609
# available countries   241
# time range            1950 - 2022
# available regions     179
# --------------------  ----------------------------------------------------------------------------------------

# %% [markdown]
# You can take a look at the available indicators

# %%
# return a list of available indicator codes
sdg.available_indicators()
# Out:
# ['ADMI.ENDOFLOWERSEC.MAT',
#  'ADMI.ENDOFLOWERSEC.READ',
#  'ADMI.ENDOFPRIM.MAT',
#  'ADMI.ENDOFPRIM.READ',
#  'ADMI.GRADE2OR3PRIM.MAT',
#  'ADMI.GRADE2OR3PRIM.READ',
#  'AIDEDUC.LOWINCOMECOUNT',
#  'AIR.1.GLAST',
#  'AIR.1.GLAST.F',
#  'AIR.1.GLAST.GPIA',
#  'AIR.1.GLAST.M',
#  'AIR.2.GPV.GLAST',
#  'AIR.2.GPV.GLAST.F',
#  'AIR.2.GPV.GLAST.GPIA',
#  'AIR.2.GPV.GLAST.M',
#  'CR.1',
#  'CR.1.ABL',
#  'CR.1.ABL.F',
#  'CR.1.ABL.GPIA',
#  'CR.1.ABL.M',
#  'CR.1.DIS',
#  'CR.1.DIS.F',
#  'CR.1.DIS.GPIA',
#  'CR.1.DIS.M',
#  'CR.1.DPIA',
#  'CR.1.F',
#  'CR.1.F.DPIA',
#  'CR.1.F.LPIA',
#  'CR.1.F.WPIA',
#  'CR.1.GPIA',
#  'CR.1.LPIA',
#  'CR.1.M',
#  'CR.1.M.DPIA',
#  'CR.1.M.LPIA',
#  'CR.1.M.WPIA',
#  'CR.1.Q1',
#  'CR.1.Q1.F',
#  'CR.1.Q1.F.LPIA',
#  'CR.1.Q1.GPIA',
#  'CR.1.Q1.LPIA',
#  'CR.1.Q1.M',
#  'CR.1.Q1.M.LPIA',
#  'CR.1.Q2',
#  'CR.1.Q2.F',
#  'CR.1.Q2.F.LPIA',
#  'CR.1.Q2.GPIA',
#  'CR.1.Q2.LPIA',
#  'CR.1.Q2.M',
#  'CR.1.Q2.M.LPIA',
#  'CR.1.Q3',
#  'CR.1.Q3.F',
#  'CR.1.Q3.F.LPIA',
#  'CR.1.Q3.GPIA',
#  'CR.1.Q3.LPIA',
#  'CR.1.Q3.M',
#  'CR.1.Q3.M.LPIA',
#  'CR.1.Q4',
#  'CR.1.Q4.F',
#  'CR.1.Q4.F.LPIA',
#  'CR.1.Q4.GPIA',
#  'CR.1.Q4.LPIA',
#  'CR.1.Q4.M',
#  'CR.1.Q4.M.LPIA',
#  'CR.1.Q5',
#  'CR.1.Q5.F',
#  'CR.1.Q5.F.LPIA',
#  'CR.1.Q5.GPIA',
#  'CR.1.Q5.LPIA',
#  'CR.1.Q5.M',
#  'CR.1.Q5.M.LPIA',
#  'CR.1.RUR',
#  'CR.1.RUR.F',
#  'CR.1.RUR.F.WPIA',
#  'CR.1.RUR.GPIA',
#  'CR.1.RUR.M',
#  'CR.1.RUR.M.WPIA',
#  'CR.1.RUR.Q1',
#  'CR.1.RUR.Q1.F',
#  'CR.1.RUR.Q1.GPIA',
#  'CR.1.RUR.Q1.M',
#  'CR.1.RUR.Q2',
#  'CR.1.RUR.Q2.F',
#  'CR.1.RUR.Q2.GPIA',
#  'CR.1.RUR.Q2.M',
#  'CR.1.RUR.Q3',
#  'CR.1.RUR.Q3.F',
#  'CR.1.RUR.Q3.GPIA',
#  'CR.1.RUR.Q3.M',
#  'CR.1.RUR.Q4',
#  'CR.1.RUR.Q4.F',
#  'CR.1.RUR.Q4.GPIA',
#  'CR.1.RUR.Q4.M',
#  'CR.1.RUR.Q5',
#  'CR.1.RUR.Q5.F',
#  'CR.1.RUR.Q5.GPIA',
#  'CR.1.RUR.Q5.M',
#  'CR.1.RUR.WPIA',
#  'CR.1.URB',
#  'CR.1.URB.F',
#  'CR.1.URB.F.WPIA',
#  'CR.1.URB.GPIA',
#  'CR.1.URB.M',
#  'CR.1.URB.M.WPIA',
#  'CR.1.URB.Q1',
#  'CR.1.URB.Q1.F',
#  'CR.1.URB.Q1.GPIA',
#  'CR.1.URB.Q1.M',
#  'CR.1.URB.Q2',
#  'CR.1.URB.Q2.F',
#  'CR.1.URB.Q2.GPIA',
#  'CR.1.URB.Q2.M',
#  'CR.1.URB.Q3',
#  'CR.1.URB.Q3.F',
#  'CR.1.URB.Q3.GPIA',
#  'CR.1.URB.Q3.M',
#  'CR.1.URB.Q4',
#  'CR.1.URB.Q4.F',
#  'CR.1.URB.Q4.GPIA',
#  'CR.1.URB.Q4.M',
#  'CR.1.URB.Q5',
#  'CR.1.URB.Q5.F',
#  'CR.1.URB.Q5.GPIA',
#  'CR.1.URB.Q5.M',
#  'CR.1.URB.WPIA',
#  'CR.1.WPIA',
#  'CR.2',
#  'CR.2.ABL',
#  'CR.2.ABL.F',
#  'CR.2.ABL.GPIA',
#  'CR.2.ABL.M',
#  'CR.2.DIS',
#  'CR.2.DIS.F',
#  'CR.2.DIS.GPIA',
#  'CR.2.DIS.M',
#  'CR.2.DPIA',
#  'CR.2.F',
#  'CR.2.F.DPIA',
#  'CR.2.F.LPIA',
#  'CR.2.F.WPIA',
#  'CR.2.GPIA',
#  'CR.2.LPIA',
#  'CR.2.M',
#  'CR.2.M.DPIA',
#  'CR.2.M.LPIA',
#  'CR.2.M.WPIA',
#  'CR.2.Q1',
#  'CR.2.Q1.F',
#  'CR.2.Q1.F.LPIA',
#  'CR.2.Q1.GPIA',
#  'CR.2.Q1.LPIA',
#  'CR.2.Q1.M',
#  'CR.2.Q1.M.LPIA',
#  'CR.2.Q2',
#  'CR.2.Q2.F',
#  'CR.2.Q2.F.LPIA',
#  'CR.2.Q2.GPIA',
#  'CR.2.Q2.LPIA',
#  'CR.2.Q2.M',
#  'CR.2.Q2.M.LPIA',
#  'CR.2.Q3',
#  'CR.2.Q3.F',
#  'CR.2.Q3.F.LPIA',
#  'CR.2.Q3.GPIA',
#  'CR.2.Q3.LPIA',
#  'CR.2.Q3.M',
#  'CR.2.Q3.M.LPIA',
#  'CR.2.Q4',
#  'CR.2.Q4.F',
#  'CR.2.Q4.F.LPIA',
#  'CR.2.Q4.GPIA',
#  'CR.2.Q4.LPIA',
#  'CR.2.Q4.M',
#  'CR.2.Q4.M.LPIA',
#  'CR.2.Q5',
#  'CR.2.Q5.F',
#  'CR.2.Q5.F.LPIA',
#  'CR.2.Q5.GPIA',
#  'CR.2.Q5.LPIA',
#  'CR.2.Q5.M',
#  'CR.2.Q5.M.LPIA',
#  'CR.2.RUR',
#  'CR.2.RUR.F',
#  'CR.2.RUR.F.WPIA',
#  'CR.2.RUR.GPIA',
#  'CR.2.RUR.M',
#  'CR.2.RUR.M.WPIA',
#  'CR.2.RUR.Q1',
#  'CR.2.RUR.Q1.F',
#  'CR.2.RUR.Q1.GPIA',
#  'CR.2.RUR.Q1.M',
#  'CR.2.RUR.Q2',
#  'CR.2.RUR.Q2.F',
#  'CR.2.RUR.Q2.GPIA',
#  'CR.2.RUR.Q2.M',
#  'CR.2.RUR.Q3',
#  'CR.2.RUR.Q3.F',
#  'CR.2.RUR.Q3.GPIA',
#  'CR.2.RUR.Q3.M',
#  'CR.2.RUR.Q4',
#  'CR.2.RUR.Q4.F',
#  'CR.2.RUR.Q4.GPIA',
#  'CR.2.RUR.Q4.M',
#  'CR.2.RUR.Q5',
#  'CR.2.RUR.Q5.F',
#  'CR.2.RUR.Q5.GPIA',
#  'CR.2.RUR.Q5.M',
#  'CR.2.RUR.WPIA',
#  'CR.2.URB',
#  'CR.2.URB.F',
#  'CR.2.URB.F.WPIA',
#  'CR.2.URB.GPIA',
#  'CR.2.URB.M',
#  'CR.2.URB.M.WPIA',
#  'CR.2.URB.Q1',
#  'CR.2.URB.Q1.F',
#  'CR.2.URB.Q1.GPIA',
#  'CR.2.URB.Q1.M',
#  'CR.2.URB.Q2',
#  'CR.2.URB.Q2.F',
#  'CR.2.URB.Q2.GPIA',
#  'CR.2.URB.Q2.M',
#  'CR.2.URB.Q3',
#  'CR.2.URB.Q3.F',
#  'CR.2.URB.Q3.GPIA',
#  'CR.2.URB.Q3.M',
#  'CR.2.URB.Q4',
#  'CR.2.URB.Q4.F',
#  'CR.2.URB.Q4.GPIA',
#  'CR.2.URB.Q4.M',
#  'CR.2.URB.Q5',
#  'CR.2.URB.Q5.F',
#  'CR.2.URB.Q5.GPIA',
#  'CR.2.URB.Q5.M',
#  'CR.2.URB.WPIA',
#  'CR.2.WPIA',
#  'CR.3',
#  'CR.3.ABL',
#  'CR.3.ABL.F',
#  'CR.3.ABL.GPIA',
#  'CR.3.ABL.M',
#  'CR.3.DIS',
#  'CR.3.DIS.F',
#  'CR.3.DIS.GPIA',
#  'CR.3.DIS.M',
#  'CR.3.DPIA',
#  'CR.3.F',
#  'CR.3.F.DPIA',
#  'CR.3.F.LPIA',
#  'CR.3.F.WPIA',
#  'CR.3.GPIA',
#  'CR.3.LPIA',
#  'CR.3.M',
#  'CR.3.M.DPIA',
#  'CR.3.M.LPIA',
#  'CR.3.M.WPIA',
#  'CR.3.Q1',
#  'CR.3.Q1.F',
#  'CR.3.Q1.F.LPIA',
#  'CR.3.Q1.GPIA',
#  'CR.3.Q1.LPIA',
#  'CR.3.Q1.M',
#  'CR.3.Q1.M.LPIA',
#  'CR.3.Q2',
#  'CR.3.Q2.F',
#  'CR.3.Q2.F.LPIA',
#  'CR.3.Q2.GPIA',
#  'CR.3.Q2.LPIA',
#  'CR.3.Q2.M',
#  'CR.3.Q2.M.LPIA',
#  'CR.3.Q3',
#  'CR.3.Q3.F',
#  'CR.3.Q3.F.LPIA',
#  'CR.3.Q3.GPIA',
#  'CR.3.Q3.LPIA',
#  'CR.3.Q3.M',
#  'CR.3.Q3.M.LPIA',
#  'CR.3.Q4',
#  'CR.3.Q4.F',
#  'CR.3.Q4.F.LPIA',
#  'CR.3.Q4.GPIA',
#  'CR.3.Q4.LPIA',
#  'CR.3.Q4.M',
#  'CR.3.Q4.M.LPIA',
#  'CR.3.Q5',
#  'CR.3.Q5.F',
#  'CR.3.Q5.F.LPIA',
#  'CR.3.Q5.GPIA',
#  'CR.3.Q5.LPIA',
#  'CR.3.Q5.M',
#  'CR.3.Q5.M.LPIA',
#  'CR.3.RUR',
#  'CR.3.RUR.F',
#  'CR.3.RUR.F.WPIA',
#  'CR.3.RUR.GPIA',
#  'CR.3.RUR.M',
#  'CR.3.RUR.M.WPIA',
#  'CR.3.RUR.Q1',
#  'CR.3.RUR.Q1.F',
#  'CR.3.RUR.Q1.GPIA',
#  'CR.3.RUR.Q1.M',
#  'CR.3.RUR.Q2',
#  'CR.3.RUR.Q2.F',
#  'CR.3.RUR.Q2.GPIA',
#  'CR.3.RUR.Q2.M',
#  'CR.3.RUR.Q3',
#  'CR.3.RUR.Q3.F',
#  'CR.3.RUR.Q3.GPIA',
#  'CR.3.RUR.Q3.M',
#  'CR.3.RUR.Q4',
#  'CR.3.RUR.Q4.F',
#  'CR.3.RUR.Q4.GPIA',
#  'CR.3.RUR.Q4.M',
#  'CR.3.RUR.Q5',
#  'CR.3.RUR.Q5.F',
#  'CR.3.RUR.Q5.GPIA',
#  'CR.3.RUR.Q5.M',
#  'CR.3.RUR.WPIA',
#  'CR.3.URB',
#  'CR.3.URB.F',
#  'CR.3.URB.F.WPIA',
#  'CR.3.URB.GPIA',
#  'CR.3.URB.M',
#  'CR.3.URB.M.WPIA',
#  'CR.3.URB.Q1',
#  'CR.3.URB.Q1.F',
#  'CR.3.URB.Q1.GPIA',
#  'CR.3.URB.Q1.M',
#  'CR.3.URB.Q2',
#  'CR.3.URB.Q2.F',
#  'CR.3.URB.Q2.GPIA',
#  'CR.3.URB.Q2.M',
#  'CR.3.URB.Q3',
#  'CR.3.URB.Q3.F',
#  'CR.3.URB.Q3.GPIA',
#  'CR.3.URB.Q3.M',
#  'CR.3.URB.Q4',
#  'CR.3.URB.Q4.F',
#  'CR.3.URB.Q4.GPIA',
#  'CR.3.URB.Q4.M',
#  'CR.3.URB.Q5',
#  'CR.3.URB.Q5.F',
#  'CR.3.URB.Q5.GPIA',
#  'CR.3.URB.Q5.M',
#  'CR.3.URB.WPIA',
#  'CR.3.WPIA',
#  'DL',
#  'DL.F',
#  'DL.GPIA',
#  'DL.HIGHSES',
#  'DL.LOWSES',
#  'DL.M',
#  'DL.OLDERADULTS',
#  'DL.WITHOUTTERTIARY',
#  'DL.WITHTERTIARY',
#  'DL.WPIA',
#  'DL.YOUNGERADULTS',
#  'EA.1T8.AG25T99',
#  'EA.1T8.AG25T99.F',
#  'EA.1T8.AG25T99.GPIA',
#  'EA.1T8.AG25T99.M',
#  'EA.1T8.AG25T99.RUR',
#  'EA.1T8.AG25T99.RUR.F',
#  'EA.1T8.AG25T99.RUR.GPIA',
#  'EA.1T8.AG25T99.RUR.M',
#  'EA.1T8.AG25T99.URB',
#  'EA.1T8.AG25T99.URB.F',
#  'EA.1T8.AG25T99.URB.GPIA',
#  'EA.1T8.AG25T99.URB.M',
#  'EA.2T8.AG25T99',
#  'EA.2T8.AG25T99.F',
#  'EA.2T8.AG25T99.GPIA',
#  'EA.2T8.AG25T99.M',
#  'EA.2T8.AG25T99.RUR',
#  'EA.2T8.AG25T99.RUR.F',
#  'EA.2T8.AG25T99.RUR.GPIA',
#  'EA.2T8.AG25T99.RUR.M',
#  'EA.2T8.AG25T99.URB',
#  'EA.2T8.AG25T99.URB.F',
#  'EA.2T8.AG25T99.URB.GPIA',
#  'EA.2T8.AG25T99.URB.M',
#  'EA.3T8.AG25T99',
#  'EA.3T8.AG25T99.F',
#  'EA.3T8.AG25T99.GPIA',
#  'EA.3T8.AG25T99.M',
#  'EA.3T8.AG25T99.RUR',
#  'EA.3T8.AG25T99.RUR.F',
#  'EA.3T8.AG25T99.RUR.GPIA',
#  'EA.3T8.AG25T99.RUR.M',
#  'EA.3T8.AG25T99.URB',
#  'EA.3T8.AG25T99.URB.F',
#  'EA.3T8.AG25T99.URB.GPIA',
#  'EA.3T8.AG25T99.URB.M',
#  'EA.4T8.AG25T99',
#  'EA.4T8.AG25T99.F',
#  'EA.4T8.AG25T99.GPIA',
#  'EA.4T8.AG25T99.M',
#  'EA.4T8.AG25T99.RUR',
#  'EA.4T8.AG25T99.RUR.F',
#  'EA.4T8.AG25T99.RUR.GPIA',
#  'EA.4T8.AG25T99.RUR.M',
#  'EA.4T8.AG25T99.URB',
#  'EA.4T8.AG25T99.URB.F',
#  'EA.4T8.AG25T99.URB.GPIA',
#  'EA.4T8.AG25T99.URB.M',
#  'EA.5T8.AG25T99',
#  'EA.5T8.AG25T99.F',
#  'EA.5T8.AG25T99.GPIA',
#  'EA.5T8.AG25T99.M',
#  'EA.5T8.AG25T99.RUR',
#  'EA.5T8.AG25T99.RUR.F',
#  'EA.5T8.AG25T99.RUR.GPIA',
#  'EA.5T8.AG25T99.RUR.M',
#  'EA.5T8.AG25T99.URB',
#  'EA.5T8.AG25T99.URB.F',
#  'EA.5T8.AG25T99.URB.GPIA',
#  'EA.5T8.AG25T99.URB.M',
#  'EA.6T8.AG25T99',
#  'EA.6T8.AG25T99.F',
#  'EA.6T8.AG25T99.GPIA',
#  'EA.6T8.AG25T99.M',
#  'EA.6T8.AG25T99.RUR',
#  'EA.6T8.AG25T99.RUR.F',
#  'EA.6T8.AG25T99.RUR.GPIA',
#  'EA.6T8.AG25T99.RUR.M',
#  'EA.6T8.AG25T99.URB',
#  'EA.6T8.AG25T99.URB.F',
#  'EA.6T8.AG25T99.URB.GPIA',
#  'EA.6T8.AG25T99.URB.M',
#  'EA.7T8.AG25T99',
#  'EA.7T8.AG25T99.F',
#  'EA.7T8.AG25T99.GPIA',
#  'EA.7T8.AG25T99.M',
#  'EA.7T8.AG25T99.RUR',
#  'EA.7T8.AG25T99.RUR.F',
#  'EA.7T8.AG25T99.RUR.GPIA',
#  'EA.7T8.AG25T99.RUR.M',
#  'EA.7T8.AG25T99.URB',
#  'EA.7T8.AG25T99.URB.F',
#  'EA.7T8.AG25T99.URB.GPIA',
#  'EA.7T8.AG25T99.URB.M',
#  'EA.8.AG25T99',
#  'EA.8.AG25T99.F',
#  'EA.8.AG25T99.GPIA',
#  'EA.8.AG25T99.M',
#  'EA.8.AG25T99.RUR',
#  'EA.8.AG25T99.RUR.F',
#  'EA.8.AG25T99.RUR.GPIA',
#  'EA.8.AG25T99.RUR.M',
#  'EA.8.AG25T99.URB',
#  'EA.8.AG25T99.URB.F',
#  'EA.8.AG25T99.URB.GPIA',
#  'EA.8.AG25T99.URB.M',
#  'EA.S1T8.AG25T99',
#  'EA.S1T8.AG25T99.F',
#  'EA.S1T8.AG25T99.GPIA',
#  'EA.S1T8.AG25T99.M',
#  'EA.S1T8.AG25T99.RUR',
#  'EA.S1T8.AG25T99.RUR.F',
#  'EA.S1T8.AG25T99.RUR.GPIA',
#  'EA.S1T8.AG25T99.RUR.M',
#  'EA.S1T8.AG25T99.URB',
#  'EA.S1T8.AG25T99.URB.F',
#  'EA.S1T8.AG25T99.URB.GPIA',
#  'EA.S1T8.AG25T99.URB.M',
#  'ESG.LOWERSEC',
#  'ESG.LOWERSEC.COGN',
#  'ESG.LOWERSEC.COGN.F',
#  'ESG.LOWERSEC.COGN.GPIA',
#  'ESG.LOWERSEC.COGN.HIGHSES',
#  'ESG.LOWERSEC.COGN.LOWSES',
#  'ESG.LOWERSEC.COGN.LPIA',
#  'ESG.LOWERSEC.COGN.M',
#  'ESG.LOWERSEC.COGN.RURAL',
#  'ESG.LOWERSEC.COGN.URBAN',
#  'ESG.LOWERSEC.COGN.WPIA',
#  'ESG.LOWERSEC.F',
#  'ESG.LOWERSEC.GPIA',
#  'ESG.LOWERSEC.HIGHSES',
#  'ESG.LOWERSEC.LOWSES',
#  'ESG.LOWERSEC.LPIA',
#  'ESG.LOWERSEC.M',
#  'ESG.LOWERSEC.NCOG.CONF',
#  'ESG.LOWERSEC.NCOG.CONF.F',
#  'ESG.LOWERSEC.NCOG.CONF.GPIA',
#  'ESG.LOWERSEC.NCOG.CONF.HIGHSES',
#  'ESG.LOWERSEC.NCOG.CONF.LOWSES',
#  'ESG.LOWERSEC.NCOG.CONF.LPIA',
#  'ESG.LOWERSEC.NCOG.CONF.M',
#  'ESG.LOWERSEC.NCOG.CONF.RURAL',
#  'ESG.LOWERSEC.NCOG.CONF.URBAN',
#  'ESG.LOWERSEC.NCOG.CONF.WPIA',
#  'ESG.LOWERSEC.NCOG.ENJO',
#  'ESG.LOWERSEC.NCOG.ENJO.F',
#  'ESG.LOWERSEC.NCOG.ENJO.GPIA',
#  'ESG.LOWERSEC.NCOG.ENJO.HIGHSES',
#  'ESG.LOWERSEC.NCOG.ENJO.LOWSES',
#  'ESG.LOWERSEC.NCOG.ENJO.LPIA',
#  'ESG.LOWERSEC.NCOG.ENJO.M',
#  'ESG.LOWERSEC.NCOG.ENJO.RURAL',
#  'ESG.LOWERSEC.NCOG.ENJO.URBAN',
#  'ESG.LOWERSEC.NCOG.ENJO.WPIA',
#  'ESG.LOWERSEC.RURAL',
#  'ESG.LOWERSEC.URBAN',
#  'ESG.LOWERSEC.WPIA',
#  'EV1524P.2T5.V',
#  'EV1524P.2T5.V.F',
#  'EV1524P.2T5.V.GPIA',
#  'EV1524P.2T5.V.M',
#  'FHLANGILP.G2T3',
#  'FHLANGILP.G2T3.F',
#  'FHLANGILP.G2T3.GPIA',
#  'FHLANGILP.G2T3.HIGHSES',
#  'FHLANGILP.G2T3.LOWSES',
#  'FHLANGILP.G2T3.LPIA',
#  'FHLANGILP.G2T3.M',
#  'FHLANGILP.G2T3.RUR',
#  'FHLANGILP.G2T3.URB',
#  'FHLANGILP.G2T3.WPIA',
#  'FHLANGILP.LOWERSEC',
#  'FHLANGILP.LOWERSEC.F',
#  'FHLANGILP.LOWERSEC.GPIA',
#  'FHLANGILP.LOWERSEC.HIGHSES',
#  'FHLANGILP.LOWERSEC.LOWSES',
#  'FHLANGILP.LOWERSEC.LPIA',
#  'FHLANGILP.LOWERSEC.M',
#  'FHLANGILP.LOWERSEC.RUR',
#  'FHLANGILP.LOWERSEC.URB',
#  'FHLANGILP.LOWERSEC.WPIA',
#  'FHLANGILP.PRIMARY',
#  'FHLANGILP.PRIMARY.F',
#  'FHLANGILP.PRIMARY.GPIA',
#  'FHLANGILP.PRIMARY.HIGHSES',
#  'FHLANGILP.PRIMARY.LOWSES',
#  'FHLANGILP.PRIMARY.LPIA',
#  'FHLANGILP.PRIMARY.M',
#  'FHLANGILP.PRIMARY.RUR',
#  'FHLANGILP.PRIMARY.URB',
#  'FHLANGILP.PRIMARY.WPIA',
#  'GAR.5T8',
#  'GAR.5T8.F',
#  'GAR.5T8.F.LPIA',
#  'GAR.5T8.F.WPIA',
#  'GAR.5T8.GPIA',
#  'GAR.5T8.LPIA',
#  'GAR.5T8.M',
#  'GAR.5T8.M.LPIA',
#  'GAR.5T8.M.WPIA',
#  'GAR.5T8.Q1',
#  'GAR.5T8.Q1.F',
#  'GAR.5T8.Q1.F.LPIA',
#  'GAR.5T8.Q1.GPIA',
#  'GAR.5T8.Q1.LPIA',
#  'GAR.5T8.Q1.M',
#  'GAR.5T8.Q1.M.LPIA',
#  'GAR.5T8.Q2',
#  'GAR.5T8.Q2.F',
#  'GAR.5T8.Q2.F.LPIA',
#  'GAR.5T8.Q2.GPIA',
#  'GAR.5T8.Q2.LPIA',
#  'GAR.5T8.Q2.M',
#  'GAR.5T8.Q2.M.LPIA',
#  'GAR.5T8.Q3',
#  'GAR.5T8.Q3.F',
#  'GAR.5T8.Q3.F.LPIA',
#  'GAR.5T8.Q3.GPIA',
#  'GAR.5T8.Q3.LPIA',
#  'GAR.5T8.Q3.M',
#  'GAR.5T8.Q3.M.LPIA',
#  'GAR.5T8.Q4',
#  'GAR.5T8.Q4.F',
#  'GAR.5T8.Q4.F.LPIA',
#  'GAR.5T8.Q4.GPIA',
#  'GAR.5T8.Q4.LPIA',
#  'GAR.5T8.Q4.M',
#  'GAR.5T8.Q4.M.LPIA',
#  'GAR.5T8.Q5',
#  'GAR.5T8.Q5.F',
#  'GAR.5T8.Q5.F.LPIA',
#  'GAR.5T8.Q5.GPIA',
#  'GAR.5T8.Q5.LPIA',
#  'GAR.5T8.Q5.M',
#  'GAR.5T8.Q5.M.LPIA',
#  'GAR.5T8.RUR',
#  'GAR.5T8.RUR.F',
#  'GAR.5T8.RUR.F.WPIA',
#  'GAR.5T8.RUR.GPIA',
#  'GAR.5T8.RUR.M',
#  'GAR.5T8.RUR.M.WPIA',
#  'GAR.5T8.RUR.Q1',
#  'GAR.5T8.RUR.Q1.F',
#  'GAR.5T8.RUR.Q1.GPIA',
#  'GAR.5T8.RUR.Q1.M',
#  'GAR.5T8.RUR.Q2',
#  'GAR.5T8.RUR.Q2.F',
#  'GAR.5T8.RUR.Q2.GPIA',
#  'GAR.5T8.RUR.Q2.M',
#  'GAR.5T8.RUR.Q3',
#  'GAR.5T8.RUR.Q3.F',
#  'GAR.5T8.RUR.Q3.GPIA',
#  'GAR.5T8.RUR.Q3.M',
#  'GAR.5T8.RUR.Q4',
#  'GAR.5T8.RUR.Q4.F',
#  'GAR.5T8.RUR.Q4.GPIA',
#  'GAR.5T8.RUR.Q4.M',
#  'GAR.5T8.RUR.Q5',
#  'GAR.5T8.RUR.Q5.F',
#  'GAR.5T8.RUR.Q5.GPIA',
#  'GAR.5T8.RUR.Q5.M',
#  'GAR.5T8.RUR.WPIA',
#  'GAR.5T8.URB',
#  'GAR.5T8.URB.F',
#  'GAR.5T8.URB.F.WPIA',
#  'GAR.5T8.URB.GPIA',
#  'GAR.5T8.URB.M',
#  'GAR.5T8.URB.M.WPIA',
#  'GAR.5T8.URB.Q1',
#  'GAR.5T8.URB.Q1.F',
#  'GAR.5T8.URB.Q1.GPIA',
#  'GAR.5T8.URB.Q1.M',
#  'GAR.5T8.URB.Q2',
#  'GAR.5T8.URB.Q2.F',
#  'GAR.5T8.URB.Q2.GPIA',
#  'GAR.5T8.URB.Q2.M',
#  'GAR.5T8.URB.Q3',
#  'GAR.5T8.URB.Q3.F',
#  'GAR.5T8.URB.Q3.GPIA',
#  'GAR.5T8.URB.Q3.M',
#  'GAR.5T8.URB.Q4',
#  'GAR.5T8.URB.Q4.F',
#  'GAR.5T8.URB.Q4.GPIA',
#  'GAR.5T8.URB.Q4.M',
#  'GAR.5T8.URB.Q5',
#  'GAR.5T8.URB.Q5.F',
#  'GAR.5T8.URB.Q5.GPIA',
#  'GAR.5T8.URB.Q5.M',
#  'GAR.5T8.URB.WPIA',
#  'GAR.5T8.WPIA',
#  'GCS.LOWERSEC',
#  'GCS.LOWERSEC.COG',
#  'GCS.LOWERSEC.COG.F',
#  'GCS.LOWERSEC.COG.GPIA',
#  'GCS.LOWERSEC.COG.HIGHSES',
#  'GCS.LOWERSEC.COG.LOWSES',
#  'GCS.LOWERSEC.COG.LPIA',
#  'GCS.LOWERSEC.COG.M',
#  'GCS.LOWERSEC.COG.RURAL',
#  'GCS.LOWERSEC.COG.URBAN',
#  'GCS.LOWERSEC.COG.WPIA',
#  'GCS.LOWERSEC.F',
#  'GCS.LOWERSEC.GPIA',
#  'GCS.LOWERSEC.HIGHSES',
#  'GCS.LOWERSEC.LOWSES',
#  'GCS.LOWERSEC.LPIA',
#  'GCS.LOWERSEC.M',
#  'GCS.LOWERSEC.NCOG.FREE',
#  'GCS.LOWERSEC.NCOG.FREE.F',
#  'GCS.LOWERSEC.NCOG.FREE.GPIA',
#  'GCS.LOWERSEC.NCOG.FREE.HIGHSES',
#  'GCS.LOWERSEC.NCOG.FREE.LOWSES',
#  'GCS.LOWERSEC.NCOG.FREE.LPIA',
#  'GCS.LOWERSEC.NCOG.FREE.M',
#  'GCS.LOWERSEC.NCOG.FREE.RURAL',
#  'GCS.LOWERSEC.NCOG.FREE.URBAN',
#  'GCS.LOWERSEC.NCOG.FREE.WPIA',
#  'GCS.LOWERSEC.NCOG.GEQU',
#  'GCS.LOWERSEC.NCOG.GEQU.F',
#  'GCS.LOWERSEC.NCOG.GEQU.GPIA',
#  'GCS.LOWERSEC.NCOG.GEQU.HIGHSES',
#  'GCS.LOWERSEC.NCOG.GEQU.LOWSES',
#  'GCS.LOWERSEC.NCOG.GEQU.LPIA',
#  'GCS.LOWERSEC.NCOG.GEQU.M',
#  'GCS.LOWERSEC.NCOG.GEQU.RURAL',
#  'GCS.LOWERSEC.NCOG.GEQU.URBAN',
#  'GCS.LOWERSEC.NCOG.GEQU.WPIA',
#  'GCS.LOWERSEC.NCOG.GLOC',
#  'GCS.LOWERSEC.NCOG.GLOC.F',
#  'GCS.LOWERSEC.NCOG.GLOC.GPIA',
#  'GCS.LOWERSEC.NCOG.GLOC.HIGHSES',
#  'GCS.LOWERSEC.NCOG.GLOC.LOWSES',
#  'GCS.LOWERSEC.NCOG.GLOC.LPIA',
#  'GCS.LOWERSEC.NCOG.GLOC.M',
#  'GCS.LOWERSEC.NCOG.GLOC.RURAL',
#  'GCS.LOWERSEC.NCOG.GLOC.URBAN',
#  'GCS.LOWERSEC.NCOG.GLOC.WPIA',
#  'GCS.LOWERSEC.NCOG.MULT',
#  'GCS.LOWERSEC.NCOG.MULT.F',
#  'GCS.LOWERSEC.NCOG.MULT.GPIA',
#  'GCS.LOWERSEC.NCOG.MULT.HIGHSES',
#  'GCS.LOWERSEC.NCOG.MULT.LOWSES',
#  'GCS.LOWERSEC.NCOG.MULT.LPIA',
#  'GCS.LOWERSEC.NCOG.MULT.M',
#  'GCS.LOWERSEC.NCOG.MULT.RURAL',
#  'GCS.LOWERSEC.NCOG.MULT.URBAN',
#  'GCS.LOWERSEC.NCOG.MULT.WPIA',
#  'GCS.LOWERSEC.NCOG.PEAC',
#  'GCS.LOWERSEC.NCOG.PEAC.F',
#  'GCS.LOWERSEC.NCOG.PEAC.GPIA',
#  'GCS.LOWERSEC.NCOG.PEAC.HIGHSES',
#  'GCS.LOWERSEC.NCOG.PEAC.LOWSES',
#  'GCS.LOWERSEC.NCOG.PEAC.LPIA',
#  'GCS.LOWERSEC.NCOG.PEAC.M',
#  'GCS.LOWERSEC.NCOG.PEAC.RURAL',
#  'GCS.LOWERSEC.NCOG.PEAC.URBAN',
#  'GCS.LOWERSEC.NCOG.PEAC.WPIA',
#  'GCS.LOWERSEC.NCOG.SDEV',
#  'GCS.LOWERSEC.NCOG.SDEV.F',
#  'GCS.LOWERSEC.NCOG.SDEV.GPIA',
#  'GCS.LOWERSEC.NCOG.SDEV.HIGHSES',
#  'GCS.LOWERSEC.NCOG.SDEV.LOWSES',
#  'GCS.LOWERSEC.NCOG.SDEV.LPIA',
#  'GCS.LOWERSEC.NCOG.SDEV.M',
#  'GCS.LOWERSEC.NCOG.SDEV.RURAL',
#  'GCS.LOWERSEC.NCOG.SDEV.URBAN',
#  'GCS.LOWERSEC.NCOG.SDEV.WPIA',
#  'GCS.LOWERSEC.NCOG.SJUS',
#  'GCS.LOWERSEC.NCOG.SJUS.F',
#  'GCS.LOWERSEC.NCOG.SJUS.GPIA',
#  'GCS.LOWERSEC.NCOG.SJUS.HIGHSES',
#  'GCS.LOWERSEC.NCOG.SJUS.LOWSES',
#  'GCS.LOWERSEC.NCOG.SJUS.LPIA',
#  'GCS.LOWERSEC.NCOG.SJUS.M',
#  'GCS.LOWERSEC.NCOG.SJUS.RURAL',
#  'GCS.LOWERSEC.NCOG.SJUS.URBAN',
#  'GCS.LOWERSEC.NCOG.SJUS.WPIA',
#  'GCS.LOWERSEC.RURAL',
#  'GCS.LOWERSEC.URBAN',
#  'GCS.LOWERSEC.WPIA',
#  'GER.0',
#  'GER.0.F',
#  'GER.0.GPIA',
#  'GER.0.M',
#  'GER.01',
#  'GER.01.F',
#  'GER.01.GPIA',
#  'GER.01.M',
#  'GER.02',
#  'GER.02.F',
#  'GER.02.GPIA',
#  'GER.02.M',
#  'GER.5T8',
#  'GER.5T8.F',
#  'GER.5T8.GPIA',
#  'GER.5T8.M',
#  'ICTSKILLATTACH',
#  'ICTSKILLATTACH.F',
#  'ICTSKILLATTACH.GPIA',
#  'ICTSKILLATTACH.M',
#  'ICTSKILLCONNEC',
#  'ICTSKILLCONNEC.F',
#  'ICTSKILLCONNEC.GPIA',
#  'ICTSKILLCONNEC.M',
#  'ICTSKILLCOPI',
#  'ICTSKILLCOPI.F',
#  'ICTSKILLCOPI.GPIA',
#  'ICTSKILLCOPI.M',
#  'ICTSKILLCREAT',
#  'ICTSKILLCREAT.F',
#  'ICTSKILLCREAT.GPIA',
#  'ICTSKILLCREAT.M',
#  'ICTSKILLDUPLIC',
#  'ICTSKILLDUPLIC.F',
#  'ICTSKILLDUPLIC.GPIA',
#  'ICTSKILLDUPLIC.M',
#  'ICTSKILLFORMULA',
#  'ICTSKILLFORMULA.F',
#  'ICTSKILLFORMULA.GPIA',
#  'ICTSKILLFORMULA.M',
#  'ICTSKILLPROGLANG',
#  'ICTSKILLPROGLANG.F',
#  'ICTSKILLPROGLANG.GPIA',
#  'ICTSKILLPROGLANG.M',
#  'ICTSKILLSOFTWARE',
#  'ICTSKILLSOFTWARE.F',
#  'ICTSKILLSOFTWARE.GPIA',
#  'ICTSKILLSOFTWARE.M',
#  'ICTSKILLTRANSFERFILE',
#  'ICTSKILLTRANSFERFILE.F',
#  'ICTSKILLTRANSFERFILE.GPIA',
#  'ICTSKILLTRANSFERFILE.M',
#  'LR.AG15T24',
#  'LR.AG15T24.F',
#  'LR.AG15T24.F.LPIA',
#  'LR.AG15T24.GPIA',
#  'LR.AG15T24.LPIA',
#  'LR.AG15T24.M',
#  'LR.AG15T24.M.LPIA',
#  'LR.AG15T24.RUR',
#  'LR.AG15T24.RUR.F',
#  'LR.AG15T24.RUR.GPIA',
#  'LR.AG15T24.RUR.M',
#  'LR.AG15T24.URB',
#  'LR.AG15T24.URB.F',
#  'LR.AG15T24.URB.GPIA',
#  'LR.AG15T24.URB.M',
#  'LR.AG15T99',
#  'LR.AG15T99.F',
#  'LR.AG15T99.F.LPIA',
#  'LR.AG15T99.GPIA',
#  'LR.AG15T99.LPIA',
#  'LR.AG15T99.M',
#  'LR.AG15T99.M.LPIA',
#  'LR.AG15T99.RUR',
#  'LR.AG15T99.RUR.F',
#  'LR.AG15T99.RUR.GPIA',
#  'LR.AG15T99.RUR.M',
#  'LR.AG15T99.URB',
#  'LR.AG15T99.URB.F',
#  'LR.AG15T99.URB.GPIA',
#  'LR.AG15T99.URB.M',
#  'LR.AG25T64',
#  'LR.AG25T64.F',
#  'LR.AG25T64.F.LPIA',
#  'LR.AG25T64.GPIA',
#  'LR.AG25T64.LPIA',
#  'LR.AG25T64.M',
#  'LR.AG25T64.M.LPIA',
#  'LR.AG25T64.RUR',
#  'LR.AG25T64.RUR.F',
#  'LR.AG25T64.RUR.GPIA',
#  'LR.AG25T64.RUR.M',
#  'LR.AG25T64.URB',
#  'LR.AG25T64.URB.F',
#  'LR.AG25T64.URB.GPIA',
#  'LR.AG25T64.URB.M',
#  'LR.AG65T99',
#  'LR.AG65T99.F',
#  'LR.AG65T99.F.LPIA',
#  'LR.AG65T99.GPIA',
#  'LR.AG65T99.LPIA',
#  'LR.AG65T99.M',
#  'LR.AG65T99.M.LPIA',
#  'LR.AG65T99.RUR',
#  'LR.AG65T99.RUR.F',
#  'LR.AG65T99.RUR.GPIA',
#  'LR.AG65T99.RUR.M',
#  'LR.AG65T99.URB',
#  'LR.AG65T99.URB.F',
#  'LR.AG65T99.URB.GPIA',
#  'LR.AG65T99.URB.M',
#  'MATH.G2T3',
#  'MATH.G2T3.F',
#  'MATH.G2T3.GPIA',
#  'MATH.G2T3.HIGHSES',
#  'MATH.G2T3.LANGTEST',
#  'MATH.G2T3.LOWSES',
#  'MATH.G2T3.LPIA',
#  'MATH.G2T3.LTPIA',
#  'MATH.G2T3.M',
#  'MATH.G2T3.NATIVE',
#  'MATH.G2T3.NONLANGTEST',
#  'MATH.G2T3.NONNATIVE',
#  'MATH.G2T3.NPIA',
#  'MATH.G2T3.RURAL',
#  'MATH.G2T3.URBAN',
#  'MATH.G2T3.WPIA',
#  'MATH.LOWERSEC',
#  'MATH.LOWERSEC.F',
#  'MATH.LOWERSEC.GPIA',
#  'MATH.LOWERSEC.HIGHSES',
#  'MATH.LOWERSEC.LANGTEST',
#  'MATH.LOWERSEC.LOWSES',
#  'MATH.LOWERSEC.LPIA',
#  'MATH.LOWERSEC.LTPIA',
#  'MATH.LOWERSEC.M',
#  'MATH.LOWERSEC.NATIVE',
#  'MATH.LOWERSEC.NONLANGTEST',
#  'MATH.LOWERSEC.NONNATIVE',
#  'MATH.LOWERSEC.NPIA',
#  'MATH.LOWERSEC.RURAL',
#  'MATH.LOWERSEC.URBAN',
#  'MATH.LOWERSEC.WPIA',
#  'MATH.PRIMARY',
#  'MATH.PRIMARY.F',
#  'MATH.PRIMARY.GPIA',
#  'MATH.PRIMARY.HIGHSES',
#  'MATH.PRIMARY.LANGTEST',
#  'MATH.PRIMARY.LOWSES',
#  'MATH.PRIMARY.LPIA',
#  'MATH.PRIMARY.LTPIA',
#  'MATH.PRIMARY.M',
#  'MATH.PRIMARY.NATIVE',
#  'MATH.PRIMARY.NONLANGTEST',
#  'MATH.PRIMARY.NONNATIVE',
#  'MATH.PRIMARY.NPIA',
#  'MATH.PRIMARY.RURAL',
#  'MATH.PRIMARY.URBAN',
#  'MATH.PRIMARY.WPIA',
#  'N.ATTACKS',
#  'NARA.AGM1',
#  'NARA.AGM1.F',
#  'NARA.AGM1.F.LPIA',
#  'NARA.AGM1.F.WPIA',
#  'NARA.AGM1.GPIA',
#  'NARA.AGM1.LPIA',
#  'NARA.AGM1.M',
#  'NARA.AGM1.M.LPIA',
#  'NARA.AGM1.M.WPIA',
#  'NARA.AGM1.Q1',
#  'NARA.AGM1.Q1.F',
#  'NARA.AGM1.Q1.F.LPIA',
#  'NARA.AGM1.Q1.GPIA',
#  'NARA.AGM1.Q1.LPIA',
#  'NARA.AGM1.Q1.M',
#  'NARA.AGM1.Q1.M.LPIA',
#  'NARA.AGM1.Q2',
#  'NARA.AGM1.Q2.F',
#  'NARA.AGM1.Q2.F.LPIA',
#  'NARA.AGM1.Q2.GPIA',
#  'NARA.AGM1.Q2.LPIA',
#  'NARA.AGM1.Q2.M',
#  'NARA.AGM1.Q2.M.LPIA',
#  'NARA.AGM1.Q3',
#  'NARA.AGM1.Q3.F',
#  'NARA.AGM1.Q3.F.LPIA',
#  'NARA.AGM1.Q3.GPIA',
#  'NARA.AGM1.Q3.LPIA',
#  'NARA.AGM1.Q3.M',
#  'NARA.AGM1.Q3.M.LPIA',
#  'NARA.AGM1.Q4',
#  'NARA.AGM1.Q4.F',
#  'NARA.AGM1.Q4.F.LPIA',
#  'NARA.AGM1.Q4.GPIA',
#  'NARA.AGM1.Q4.LPIA',
#  'NARA.AGM1.Q4.M',
#  'NARA.AGM1.Q4.M.LPIA',
#  'NARA.AGM1.Q5',
#  'NARA.AGM1.Q5.F',
#  'NARA.AGM1.Q5.F.LPIA',
#  'NARA.AGM1.Q5.GPIA',
#  'NARA.AGM1.Q5.LPIA',
#  'NARA.AGM1.Q5.M',
#  'NARA.AGM1.Q5.M.LPIA',
#  'NARA.AGM1.RUR',
#  'NARA.AGM1.RUR.F',
#  'NARA.AGM1.RUR.F.WPIA',
#  'NARA.AGM1.RUR.GPIA',
#  'NARA.AGM1.RUR.M',
#  'NARA.AGM1.RUR.M.WPIA',
#  'NARA.AGM1.RUR.Q1',
#  'NARA.AGM1.RUR.Q1.F',
#  'NARA.AGM1.RUR.Q1.GPIA',
#  'NARA.AGM1.RUR.Q1.M',
#  'NARA.AGM1.RUR.Q2',
#  'NARA.AGM1.RUR.Q2.F',
#  'NARA.AGM1.RUR.Q2.GPIA',
#  'NARA.AGM1.RUR.Q2.M',
#  'NARA.AGM1.RUR.Q3',
#  'NARA.AGM1.RUR.Q3.F',
#  'NARA.AGM1.RUR.Q3.GPIA',
#  'NARA.AGM1.RUR.Q3.M',
#  'NARA.AGM1.RUR.Q4',
#  'NARA.AGM1.RUR.Q4.F',
#  'NARA.AGM1.RUR.Q4.GPIA',
#  'NARA.AGM1.RUR.Q4.M',
#  'NARA.AGM1.RUR.Q5',
#  'NARA.AGM1.RUR.Q5.F',
#  'NARA.AGM1.RUR.Q5.GPIA',
#  'NARA.AGM1.RUR.Q5.M',
#  'NARA.AGM1.RUR.WPIA',
#  'NARA.AGM1.URB',
#  'NARA.AGM1.URB.F',
#  'NARA.AGM1.URB.F.WPIA',
#  'NARA.AGM1.URB.GPIA',
#  'NARA.AGM1.URB.M',
#  'NARA.AGM1.URB.M.WPIA',
#  'NARA.AGM1.URB.Q1',
#  'NARA.AGM1.URB.Q1.F',
#  'NARA.AGM1.URB.Q1.GPIA',
#  'NARA.AGM1.URB.Q1.M',
#  'NARA.AGM1.URB.Q2',
#  'NARA.AGM1.URB.Q2.F',
#  'NARA.AGM1.URB.Q2.GPIA',
#  'NARA.AGM1.URB.Q2.M',
#  'NARA.AGM1.URB.Q3',
#  'NARA.AGM1.URB.Q3.F',
#  'NARA.AGM1.URB.Q3.GPIA',
#  'NARA.AGM1.URB.Q3.M',
#  'NARA.AGM1.URB.Q4',
#  'NARA.AGM1.URB.Q4.F',
#  'NARA.AGM1.URB.Q4.GPIA',
#  'NARA.AGM1.URB.Q4.M',
#  'NARA.AGM1.URB.Q5',
#  'NARA.AGM1.URB.Q5.F',
#  'NARA.AGM1.URB.Q5.GPIA',
#  'NARA.AGM1.URB.Q5.M',
#  'NARA.AGM1.URB.WPIA',
#  'NARA.AGM1.WPIA',
#  'NERA.AGM1.CP',
#  'NERA.AGM1.F.CP',
#  'NERA.AGM1.GPIA.CP',
#  'NERA.AGM1.M.CP',
#  'OAEPG.1',
#  'OAEPG.1.F',
#  'OAEPG.1.GPIA',
#  'OAEPG.1.M',
#  'OAEPG.2.GPV',
#  'OAEPG.2.GPV.F',
#  'OAEPG.2.GPV.GPIA',
#  'OAEPG.2.GPV.M',
#  'ODAFLOW.VOLUMESCHOLARSHIP',
#  ...]

# %%
# get the names of indicators
sdg.available_indicators(as_names=True)
# Out:
# [' Administration of a nationally-representative learning assessment at the end of lower secondary education in mathematics (number)',
#  ' Administration of a nationally-representative learning assessment at the end of lower secondary education in reading (number)',
#  ' Administration of a nationally-representative learning assessment at the end of primary in mathematics (number)',
#  ' Administration of a nationally-representative learning assessment at the end of primary in reading (number)',
#  ' Administration of a nationally representative learning assessment in Grade 2 or 3 in mathematics (number)',
#  ' Administration of a nationally representative learning assessment in Grade 2 or 3 in reading (number)',
#  'Percentage of total aid to education allocated to least developed countries (%)',
#  'Gross intake ratio to the last grade of primary education, both sexes (%)',
#  'Gross intake ratio to the last grade of primary education, female (%)',
#  'Gross intake ratio to the last grade of primary education, adjusted gender parity index (GPIA)',
#  'Gross intake ratio to the last grade of primary education, male (%)',
#  'Gross intake ratio to the last grade of lower secondary general education, both sexes (%)',
#  'Gross intake ratio to the last grade of lower secondary general education, female (%)',
#  'Gross intake ratio to the last grade of lower secondary general education, adjusted gender parity index (GPIA)',
#  'Gross intake ratio to the last grade of lower secondary general education, male (%)',
#  'Completion rate, primary education, both sexes (%)',
#  'Completion rate, primary education, not disabled, both sexes (%)',
#  'Completion rate, primary education, not disabled, female (%)',
#  'Completion rate, primary education, not disabled, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, not disabled, male (%)',
#  'Completion rate, primary education, disabled, both sexes (%)',
#  'Completion rate, primary education, disabled, female (%)',
#  'Completion rate, primary education, disabled, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, disabled, male (%)',
#  'Completion rate, primary education, adjusted disability parity index (DPIA)',
#  'Completion rate, primary education, female (%)',
#  'Completion rate, primary education, female, adjusted disability parity index (DPIA)',
#  'Completion rate, primary education, female, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, female, adjusted wealth parity index (WPIA)',
#  'Completion rate, primary education, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, male (%)',
#  'Completion rate, primary education, male, adjusted disability parity index (DPIA)',
#  'Completion rate, primary education, male, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, male, adjusted wealth parity index (WPIA)',
#  'Completion rate, primary education, poorest quintile, both sexes (%)',
#  'Completion rate, primary education, poorest quintile, female (%)',
#  'Completion rate, primary education, poorest quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, poorest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, poorest quintile, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, poorest quintile, male (%)',
#  'Completion rate, primary education, poorest quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, second quintile, both sexes (%)',
#  'Completion rate, primary education, second quintile, female (%)',
#  'Completion rate, primary education, second quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, second quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, second quintile, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, second quintile, male (%)',
#  'Completion rate, primary education, second quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, middle quintile, both sexes (%)',
#  'Completion rate, primary education, middle quintile, female (%)',
#  'Completion rate, primary education, middle quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, middle quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, middle quintile, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, middle quintile, male (%)',
#  'Completion rate, primary education, middle quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, fourth quintile, both sexes (%)',
#  'Completion rate, primary education, fourth quintile, female (%)',
#  'Completion rate, primary education, fourth quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, fourth quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, fourth quintile, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, fourth quintile, male (%)',
#  'Completion rate, primary education, fourth quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, richest quintile, both sexes (%)',
#  'Completion rate, primary education, richest quintile, female (%)',
#  'Completion rate, primary education, richest quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, richest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, richest quintile, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, richest quintile, male (%)',
#  'Completion rate, primary education, richest quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, primary education, rural, both sexes (%)',
#  'Completion rate, primary education, rural, female (%)',
#  'Completion rate, primary education, rural, female, adjusted wealth parity index (WPIA)',
#  'Completion rate, primary education, rural, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, rural, male (%)',
#  'Completion rate, primary education, rural, male, adjusted wealth parity index (WPIA)',
#  'Completion rate, primary education, rural, poorest quintile, both sexes (%)',
#  'Completion rate, primary education, rural, poorest quintile, female (%)',
#  'Completion rate, primary education, rural, poorest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, rural, poorest quintile, male (%)',
#  'Completion rate, primary education, rural, second quintile, both sexes (%)',
#  'Completion rate, primary education, rural, second quintile, female (%)',
#  'Completion rate, primary education, rural, second quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, rural, second quintile, male (%)',
#  'Completion rate, primary education, rural, middle quintile, both sexes (%)',
#  'Completion rate, primary education, rural, middle quintile, female (%)',
#  'Completion rate, primary education, rural, middle quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, rural, middle quintile, male (%)',
#  'Completion rate, primary education, rural, fourth quintile, both sexes (%)',
#  'Completion rate, primary education, rural, fourth quintile, female (%)',
#  'Completion rate, primary education, rural, fourth quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, rural, fourth quintile, male (%)',
#  'Completion rate, primary education, rural, richest quintile, both sexes (%)',
#  'Completion rate, primary education, rural, richest quintile, female (%)',
#  'Completion rate, primary education, rural, richest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, rural, richest quintile, male (%)',
#  'Completion rate, primary education, rural, adjusted wealth parity index (WPIA)',
#  'Completion rate, primary education, urban, both sexes (%)',
#  'Completion rate, primary education, urban, female (%)',
#  'Completion rate, primary education, urban, female, adjusted wealth parity index (WPIA)',
#  'Completion rate, primary education, urban, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, urban, male (%)',
#  'Completion rate, primary education, urban, male, adjusted wealth parity index (WPIA)',
#  'Completion rate, primary education, urban, poorest quintile, both sexes (%)',
#  'Completion rate, primary education, urban, poorest quintile, female (%)',
#  'Completion rate, primary education, urban, poorest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, urban, poorest quintile, male (%)',
#  'Completion rate, primary education, urban, second quintile, both sexes (%)',
#  'Completion rate, primary education, urban, second quintile, female (%)',
#  'Completion rate, primary education, urban, second quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, urban, second quintile, male (%)',
#  'Completion rate, primary education, urban, middle quintile, both sexes (%)',
#  'Completion rate, primary education, urban, middle quintile, female (%)',
#  'Completion rate, primary education, urban, middle quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, urban, middle quintile, male (%)',
#  'Completion rate, primary education, urban, fourth quintile, both sexes (%)',
#  'Completion rate, primary education, urban, fourth quintile, female (%)',
#  'Completion rate, primary education, urban, fourth quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, urban, fourth quintile, male (%)',
#  'Completion rate, primary education, urban, richest quintile, both sexes (%)',
#  'Completion rate, primary education, urban, richest quintile, female (%)',
#  'Completion rate, primary education, urban, richest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, primary education, urban, richest quintile, male (%)',
#  'Completion rate, primary education, urban, adjusted wealth parity index (WPIA)',
#  'Completion rate, primary education, adjusted wealth parity index (WPIA)',
#  'Completion rate, lower secondary education, both sexes (%)',
#  'Completion rate, lower secondary education, not disabled, both sexes (%)',
#  'Completion rate, lower secondary education, not disabled, female (%)',
#  'Completion rate, lower secondary education, not disabled, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, not disabled, male (%)',
#  'Completion rate, lower secondary education, disabled, both sexes (%)',
#  'Completion rate, lower secondary education, disabled, female (%)',
#  'Completion rate, lower secondary education, disabled, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, disabled, male (%)',
#  'Completion rate, lower secondary education, adjusted disability parity index (DPIA)',
#  'Completion rate, lower secondary education, female (%)',
#  'Completion rate, lower secondary education, female, adjusted disability parity index (DPIA)',
#  'Completion rate, lower secondary education, female, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, female, adjusted wealth parity index (WPIA)',
#  'Completion rate, lower secondary education, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, male (%)',
#  'Completion rate, lower secondary education, male, adjusted disability parity index (DPIA)',
#  'Completion rate, lower secondary education, male, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, male, adjusted wealth parity index (WPIA)',
#  'Completion rate, lower secondary education, poorest quintile, both sexes (%)',
#  'Completion rate, lower secondary education, poorest quintile, female (%)',
#  'Completion rate, lower secondary education, poorest quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, poorest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, poorest quintile, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, poorest quintile, male (%)',
#  'Completion rate, lower secondary education, poorest quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, second quintile, both sexes (%)',
#  'Completion rate, lower secondary education, second quintile, female (%)',
#  'Completion rate, lower secondary education, second quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, second quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, second quintile, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, second quintile, male (%)',
#  'Completion rate, lower secondary education, second quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, middle quintile, both sexes (%)',
#  'Completion rate, lower secondary education, middle quintile, female (%)',
#  'Completion rate, lower secondary education, middle quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, middle quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, middle quintile, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, middle quintile, male (%)',
#  'Completion rate, lower secondary education, middle quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, fourth quintile, both sexes (%)',
#  'Completion rate, lower secondary education, fourth quintile, female (%)',
#  'Completion rate, lower secondary education, fourth quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, fourth quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, fourth quintile, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, fourth quintile, male (%)',
#  'Completion rate, lower secondary education, fourth quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, richest quintile, both sexes (%)',
#  'Completion rate, lower secondary education, richest quintile, female (%)',
#  'Completion rate, lower secondary education, richest quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, richest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, richest quintile, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, richest quintile, male (%)',
#  'Completion rate, lower secondary education, richest quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, lower secondary education, rural, both sexes (%)',
#  'Completion rate, lower secondary education, rural, female (%)',
#  'Completion rate, lower secondary education, rural, female, adjusted wealth parity index (WPIA)',
#  'Completion rate, lower secondary education, rural, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, rural, male (%)',
#  'Completion rate, lower secondary education, rural, male, adjusted wealth parity index (WPIA)',
#  'Completion rate, lower secondary education, rural, poorest quintile, both sexes (%)',
#  'Completion rate, lower secondary education, rural, poorest quintile, female (%)',
#  'Completion rate, lower secondary education, rural, poorest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, rural, poorest quintile, male (%)',
#  'Completion rate, lower secondary education, rural, second quintile, both sexes (%)',
#  'Completion rate, lower secondary education, rural, second quintile, female (%)',
#  'Completion rate, lower secondary education, rural, second quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, rural, second quintile, male (%)',
#  'Completion rate, lower secondary education, rural, middle quintile, both sexes (%)',
#  'Completion rate, lower secondary education, rural, middle quintile, female (%)',
#  'Completion rate, lower secondary education, rural, middle quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, rural, middle quintile, male (%)',
#  'Completion rate, lower secondary education, rural, fourth quintile, both sexes (%)',
#  'Completion rate, lower secondary education, rural, fourth quintile, female (%)',
#  'Completion rate, lower secondary education, rural, fourth quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, rural, fourth quintile, male (%)',
#  'Completion rate, lower secondary education, rural, richest quintile, both sexes (%)',
#  'Completion rate, lower secondary education, rural, richest quintile, female (%)',
#  'Completion rate, lower secondary education, rural, richest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, rural, richest quintile, male (%)',
#  'Completion rate, lower secondary education, rural, adjusted wealth parity index (WPIA)',
#  'Completion rate, lower secondary education, urban, both sexes (%)',
#  'Completion rate, lower secondary education, urban, female (%)',
#  'Completion rate, lower secondary education, urban, female, adjusted wealth parity index (WPIA)',
#  'Completion rate, lower secondary education, urban, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, urban, male (%)',
#  'Completion rate, lower secondary education, urban, male, adjusted wealth parity index (WPIA)',
#  'Completion rate, lower secondary education, urban, poorest quintile, both sexes (%)',
#  'Completion rate, lower secondary education, urban, poorest quintile, female (%)',
#  'Completion rate, lower secondary education, urban, poorest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, urban, poorest quintile, male (%)',
#  'Completion rate, lower secondary education, urban, second quintile, both sexes (%)',
#  'Completion rate, lower secondary education, urban, second quintile, female (%)',
#  'Completion rate, lower secondary education, urban, second quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, urban, second quintile, male (%)',
#  'Completion rate, lower secondary education, urban, middle quintile, both sexes (%)',
#  'Completion rate, lower secondary education, urban, middle quintile, female (%)',
#  'Completion rate, lower secondary education, urban, middle quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, urban, middle quintile, male (%)',
#  'Completion rate, lower secondary education, urban, fourth quintile, both sexes (%)',
#  'Completion rate, lower secondary education, urban, fourth quintile, female (%)',
#  'Completion rate, lower secondary education, urban, fourth quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, urban, fourth quintile, male (%)',
#  'Completion rate, lower secondary education, urban, richest quintile, both sexes (%)',
#  'Completion rate, lower secondary education, urban, richest quintile, female (%)',
#  'Completion rate, lower secondary education, urban, richest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, lower secondary education, urban, richest quintile, male (%)',
#  'Completion rate, lower secondary education, urban, adjusted wealth parity index (WPIA)',
#  'Completion rate, lower secondary education, adjusted wealth parity index (WPIA)',
#  'Completion rate, upper secondary education, both sexes (%)',
#  'Completion rate, upper secondary education, not disabled, both sexes (%)',
#  'Completion rate, upper secondary education, not disabled, female (%)',
#  'Completion rate, upper secondary education, not disabled, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, not disabled, male (%)',
#  'Completion rate, upper secondary education, disabled, both sexes (%)',
#  'Completion rate, upper secondary education, disabled, female (%)',
#  'Completion rate, upper secondary education, disabled, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, disabled, male (%)',
#  'Completion rate, upper secondary education, adjusted disability parity index (DPIA)',
#  'Completion rate, upper secondary education, female (%)',
#  'Completion rate, upper secondary education, female, adjusted disability parity index (DPIA)',
#  'Completion rate, upper secondary education, female, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, female, adjusted wealth parity index (WPIA)',
#  'Completion rate, upper secondary education, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, male (%)',
#  'Completion rate, upper secondary education, male, adjusted disability parity index (DPIA)',
#  'Completion rate, upper secondary education, male, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, male, adjusted wealth parity index (WPIA)',
#  'Completion rate, upper secondary education, poorest quintile, both sexes (%)',
#  'Completion rate, upper secondary education, poorest quintile, female (%)',
#  'Completion rate, upper secondary education, poorest quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, poorest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, poorest quintile, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, poorest quintile, male (%)',
#  'Completion rate, upper secondary education, poorest quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, second quintile, both sexes (%)',
#  'Completion rate, upper secondary education, second quintile, female (%)',
#  'Completion rate, upper secondary education, second quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, second quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, second quintile, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, second quintile, male (%)',
#  'Completion rate, upper secondary education, second quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, middle quintile, both sexes (%)',
#  'Completion rate, upper secondary education, middle quintile, female (%)',
#  'Completion rate, upper secondary education, middle quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, middle quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, middle quintile, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, middle quintile, male (%)',
#  'Completion rate, upper secondary education, middle quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, fourth quintile, both sexes (%)',
#  'Completion rate, upper secondary education, fourth quintile, female (%)',
#  'Completion rate, upper secondary education, fourth quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, fourth quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, fourth quintile, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, fourth quintile, male (%)',
#  'Completion rate, upper secondary education, fourth quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, richest quintile, both sexes (%)',
#  'Completion rate, upper secondary education, richest quintile, female (%)',
#  'Completion rate, upper secondary education, richest quintile, female, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, richest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, richest quintile, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, richest quintile, male (%)',
#  'Completion rate, upper secondary education, richest quintile, male, adjusted location parity index (LPIA)',
#  'Completion rate, upper secondary education, rural, both sexes (%)',
#  'Completion rate, upper secondary education, rural, female (%)',
#  'Completion rate, upper secondary education, rural, female, adjusted wealth parity index (WPIA)',
#  'Completion rate, upper secondary education, rural, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, rural, male (%)',
#  'Completion rate, upper secondary education, rural, male, adjusted wealth parity index (WPIA)',
#  'Completion rate, upper secondary education, rural, poorest quintile, both sexes (%)',
#  'Completion rate, upper secondary education, rural, poorest quintile, female (%)',
#  'Completion rate, upper secondary education, rural, poorest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, rural, poorest quintile, male (%)',
#  'Completion rate, upper secondary education, rural, second quintile, both sexes (%)',
#  'Completion rate, upper secondary education, rural, second quintile, female (%)',
#  'Completion rate, upper secondary education, rural, second quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, rural, second quintile, male (%)',
#  'Completion rate, upper secondary education, rural, middle quintile, both sexes (%)',
#  'Completion rate, upper secondary education, rural, middle quintile, female (%)',
#  'Completion rate, upper secondary education, rural, middle quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, rural, middle quintile, male (%)',
#  'Completion rate, upper secondary education, rural, fourth quintile, both sexes (%)',
#  'Completion rate, upper secondary education, rural, fourth quintile, female (%)',
#  'Completion rate, upper secondary education, rural, fourth quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, rural, fourth quintile, male (%)',
#  'Completion rate, upper secondary education, rural, richest quintile, both sexes (%)',
#  'Completion rate, upper secondary education, rural, richest quintile, female (%)',
#  'Completion rate, upper secondary education, rural, richest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, rural, richest quintile, male (%)',
#  'Completion rate, upper secondary education, rural, adjusted wealth parity index (WPIA)',
#  'Completion rate, upper secondary education, urban, both sexes (%)',
#  'Completion rate, upper secondary education, urban, female (%)',
#  'Completion rate, upper secondary education, urban, female, adjusted wealth parity index (WPIA)',
#  'Completion rate, upper secondary education, urban, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, urban, male (%)',
#  'Completion rate, upper secondary education, urban, male, adjusted wealth parity index (WPIA)',
#  'Completion rate, upper secondary education, urban, poorest quintile, both sexes (%)',
#  'Completion rate, upper secondary education, urban, poorest quintile, female (%)',
#  'Completion rate, upper secondary education, urban, poorest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, urban, poorest quintile, male (%)',
#  'Completion rate, upper secondary education, urban, second quintile, both sexes (%)',
#  'Completion rate, upper secondary education, urban, second quintile, female (%)',
#  'Completion rate, upper secondary education, urban, second quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, urban, second quintile, male (%)',
#  'Completion rate, upper secondary education, urban, middle quintile, both sexes (%)',
#  'Completion rate, upper secondary education, urban, middle quintile, female (%)',
#  'Completion rate, upper secondary education, urban, middle quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, urban, middle quintile, male (%)',
#  'Completion rate, upper secondary education, urban, fourth quintile, both sexes (%)',
#  'Completion rate, upper secondary education, urban, fourth quintile, female (%)',
#  'Completion rate, upper secondary education, urban, fourth quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, urban, fourth quintile, male (%)',
#  'Completion rate, upper secondary education, urban, richest quintile, both sexes (%)',
#  'Completion rate, upper secondary education, urban, richest quintile, female (%)',
#  'Completion rate, upper secondary education, urban, richest quintile, adjusted gender parity index (GPIA)',
#  'Completion rate, upper secondary education, urban, richest quintile, male (%)',
#  'Completion rate, upper secondary education, urban, adjusted wealth parity index (WPIA)',
#  'Completion rate, upper secondary education, adjusted wealth parity index (WPIA)',
#  'Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills (%)',
#  'Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills, female (%)',
#  'Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills, adjusted gender parity index (GPIA)',
#  'Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills, high socio-economic status (%)',
#  'Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills, low socio-economic status (%)',
#  'Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills, male (%)',
#  'Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills, older adults(%)',
#  'Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills, without tertiary education (%)',
#  'Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills, with tertiary education (%)',
#  'Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills, adjusted wealth parity index (WPIA)',
#  'Percentage of youth/adults who have achieved at least a minimum level of proficiency in digital literacy skills, younger adults (%)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, both sexes (%)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, female (%)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, male (%)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, rural, both sexes (%)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, rural, female (%)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, rural, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, rural, male (%)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, urban, both sexes (%)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, urban, female (%)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, urban, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed primary education or higher, population 25+ years, urban, male (%)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, both sexes (%)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, female (%)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, male (%)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, rural, both sexes (%)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, rural, female (%)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, rural, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, rural, male (%)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, urban, both sexes (%)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, urban, female (%)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, urban, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed lower secondary education or higher, population 25+ years, urban, male (%)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, both sexes (%)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, female (%)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, male (%)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, rural, both sexes (%)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, rural, female (%)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, rural, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, rural, male (%)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, urban, both sexes (%)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, urban, female (%)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, urban, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed upper secondary education or higher, population 25+ years, urban, male (%)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, both sexes (%)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, female (%)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, male (%)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, rural, both sexes (%)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, rural, female (%)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, rural, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, rural, male (%)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, urban, both sexes (%)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, urban, female (%)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, urban, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed post-secondary non-tertiary education or higher, population 25+ years, urban, male (%)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, both sexes (%)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, female (%)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, male (%)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, rural, both sexes (%)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, rural, female (%)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, rural, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, rural, male (%)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, urban, both sexes (%)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, urban, female (%)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, urban, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed short-cycle tertiary education or higher, population 25+ years, urban, male (%)',
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, both sexes (%)",
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, female (%)",
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, adjusted gender parity index (GPIA)",
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, male (%)",
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, rural, both sexes (%)",
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, rural, female (%)",
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, rural, adjusted gender parity index (GPIA)",
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, rural, male (%)",
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, urban, both sexes (%)",
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, urban, female (%)",
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, urban, adjusted gender parity index (GPIA)",
#  "Educational attainment rate, completed Bachelor's or equivalent education or higher, population 25+ years, urban, male (%)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, both sexes (%)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, female (%)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, adjusted gender parity index (GPIA)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, male (%)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, rural, both sexes (%)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, rural, female (%)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, rural, adjusted gender parity index (GPIA)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, rural, male (%)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, urban, both sexes (%)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, urban, female (%)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, urban, adjusted gender parity index (GPIA)",
#  "Educational attainment rate, completed Master's or equivalent education or higher, population 25+ years, urban, male (%)",
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, both sexes (%)',
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, female (%)',
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, male (%)',
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, rural, both sexes (%)',
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, rural, female (%)',
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, rural, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, rural, male (%)',
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, urban, both sexes (%)',
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, urban, female (%)',
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, urban, adjusted gender parity index (GPIA)',
#  'Educational attainment rate, completed Doctoral or equivalent education, population 25+ years, urban, male (%)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, both sexes (%)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, female (%)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, adjusted gender parity index (GPIA)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, male (%)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, rural, both sexes (%)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, rural, female (%)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, rural, adjusted gender parity index (GPIA)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, rural, male (%)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, urban, both sexes (%)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, urban, female (%)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, urban, adjusted gender parity index (GPIA)',
#  'Educational attainment: at least some primary (ISCED 1), population 25+ years, urban, male (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience, both sexes (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Cognitive dimension, both sexes (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Cognitive dimension, female (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Cognitive dimension – adjusted gender parity index (GPIA)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Cognitive dimension, high socio-economic status (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Cognitive dimension, low socio-economic status (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Cognitive dimension – adjusted location parity index (LPIA)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Cognitive dimension, male (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Cognitive dimension, rural (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Cognitive dimension, urban (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Cognitive dimension – adjusted wealth parity index (WPIA)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience, female (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – adjusted gender parity index (GPIA)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience, high socio-economic status (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience, low socio-economic status (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – adjusted location parity index (LPIA)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience, male (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Non-cognitive dimension - Confidence, both sexes (%)',
#  'Percentage of students in lower secondary showing proficiency in knowledge of environmental science and geoscience – Non-cognitive dimension – Confidence, female (%)',
# ...
#  'Proportion of students at the end of primary education achieving at least a minimum proficiency level in mathematics, spoke the language of the test at home, both sexes (%)',
#  'Proportion of students at the end of primary education achieving at least a minimum proficiency level in mathematics, very poor socioeconomic background, both sexes (%)',
#  'Proportion of students at the end of primary achieving at least a minimum proficiency level in mathematics, adjusted location parity index (LPIA)',
#  'Proportion of students at the end of primary education achieving at least a minimum proficiency level in mathematics, adjusted speaks language of the test parity index (LTPIA)',
#  'Proportion of students at the end of primary education achieving at least a minimum proficiency level in mathematics, male (%)',
#  'Proportion of students at the end of primary education achieving at least a minimum proficiency level in mathematics, non-immigrant background, both sexes (%)',
#  'Proportion of students at the end of primary education achieving at least a minimum proficiency level in mathematics, did not speak the language of the test at home, both sexes (%)',
#  'Proportion of students at the end of primary education achieving at least a minimum proficiency level in mathematics, immigrant background, both sexes (%)',
#  'Proportion of students at the end of primary education achieving at least a minimum proficiency level in mathematics, adjusted native parity index (NPIA)',
#  'Proportion of students at the end of primary education achieving at least a minimum proficiency level in mathematics, rural areas, both sexes (%)',
#  'Proportion of students at the end of primary education achieving at least a minimum proficiency level in mathematics, urban areas, both sexes (%)',
#  'Proportion of students at the end of primary achieving at least a minimum proficiency level in mathematics, adjusted wealth parity index (WPIA)',
#  'Number of attacks on students, personnel and institutions',
#  'Adjusted net attendance rate, one year before the official primary entry age, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, female, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, female, adjusted wealth parity index (WPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, male, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, male, adjusted wealth parity index (WPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, poorest quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, poorest quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, poorest quintile, female, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, poorest quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, poorest quintile, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, poorest quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, poorest quintile, male, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, second quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, second quintile, female (%)',
#  'Adjusted attendance rate, one year before the official primary entry age, second quintile, female, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, second quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, second quintile, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, second quintile, male (%)',
#  'Adjusted attendance rate, one year before the official primary entry age, second quintile, male, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, middle quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, middle quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, middle quintile, female, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, middle quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, middle quintile, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, middle quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, middle quintile, male, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, fourth quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, fourth quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, fourth quintile, female, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, fourth quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, fourth quintile, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, fourth quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, fourth quintile, male, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, richest quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, richest quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, richest quintile, female, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, richest quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, richest quintile, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, richest quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, richest quintile, male, adjusted location parity index (LPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, female, adjusted wealth parity index (WPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, male  (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, male, adjusted wealth parity index (WPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, poorest quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, poorest quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, poorest quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, poorest quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, second quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, second quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, second quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, second quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, middle quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, middle quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, middle quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, middle quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, fourth quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, fourth quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, fourth quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, fourth quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, richest quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, richest quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, richest quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, richest quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, rural, adjusted wealth parity index (WPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, female, adjusted wealth parity index (WPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, male  (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, male, adjusted wealth parity index (WPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, poorest quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, poorest quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, poorest quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, poorest quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, second quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, second quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, second quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, second quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, middle quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, middle quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, middle quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, middle quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, fourth quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, fourth quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, fourth quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, fourth quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, richest quintile, both sexes (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, richest quintile, female (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, richest quintile, adjusted gender parity index (GPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, richest quintile, male (%)',
#  'Adjusted net attendance rate, one year before the official primary entry age, urban, adjusted wealth parity index (WPIA)',
#  'Adjusted net attendance rate, one year before the official primary entry age, adjusted wealth parity index (WPIA)',
#  'Adjusted net enrolment rate, one year before the official primary entry age, both sexes (%)',
#  'Adjusted net enrolment rate, one year before the official primary entry age, female (%)',
#  'Adjusted net enrolment rate, one year before the official primary entry age, adjusted gender parity index (GPIA)',
#  'Adjusted net enrolment rate, one year before the official primary entry age, male (%)',
#  'Percentage of pupils enrolled in primary education who are at least 2 years over-age for their current grade, both sexes (%)',
#  'Percentage of pupils enrolled in primary education who are at least 2 years over-age for their current grade, female (%)',
#  'Proportion of pupils enrolled in primary education who are at least 2 years over-age for their current grade, adjusted gender parity index (GPIA)',
#  'Percentage of pupils enrolled in primary education who are at least 2 years over-age for their current grade, male (%)',
#  'Percentage of pupils enrolled in lower secondary general education who are at least 2 years over-age for their current grade, both sexes (%)',
#  'Percentage of pupils enrolled in lower secondary general education who are at least 2 years over-age for their current grade, female (%)',
#  'Proportion of pupils enrolled in lower secondary general education who are at least 2 years over-age for their current grade, adjusted gender parity index (GPIA)',
#  'Percentage of pupils enrolled in lower secondary general education who are at least 2 years over-age for their current grade, male (%)',
#  'Volume of official development assistance flows for scholarships by sector and type of study, constant US$ ',
#  ...]

# %% [markdown]
# You can explore the countries that are available

# %%
# get a list of available countries
sdg.available_countries()
# Out:
# ['AFG',
#  'ALB',
#  'DZA',
#  'ASM',
#  'AND',
#  'AGO',
#  'AIA',
#  'ATG',
#  'ARG',
#  'ARM',
#  'ABW',
#  'AUS',
#  'AZE',
#  'AUT',
#  'BHS',
#  'BHR',
#  'BGD',
#  'BRB',
#  'BEL',
#  'BIH',
#  'BLZ',
#  'BMU',
#  'BTN',
#  'BOL',
#  'BWA',
#  'BRA',
#  'SLB',
#  'PLW',
#  'BRN',
#  'BGR',
#  'HRV',
#  'MMR',
#  'BDI',
#  'CMR',
#  'CAN',
#  'CPV',
#  'CYM',
#  'CAF',
#  'TCD',
#  'CHL',
#  'CHN',
#  'COL',
#  'COM',
#  'MYT',
#  'COG',
#  'COK',
#  'CRI',
#  'CUB',
#  'CYP',
#  'CZE',
#  'BEN',
#  'DNK',
#  'DMA',
#  'DOM',
#  'ECU',
#  'EGY',
#  'SLV',
#  'GNQ',
#  'ERI',
#  'EST',
#  'ETH',
#  'FRO',
#  'FLK',
#  'FJI',
#  'FIN',
#  'ALA',
#  'FRA',
#  'GUF',
#  'PYF',
#  'DJI',
#  'GAB',
#  'GMB',
#  'GEO',
#  'DEU',
#  'GHA',
#  'GIB',
#  'KIR',
#  'GRC',
#  'GRL',
#  'GRD',
#  'GLP',
#  'GUM',
#  'GTM',
#  'GIN',
#  'GUY',
#  'HTI',
#  'VAT',
#  'HND',
#  'HKG',
#  'HUN',
#  'ISL',
#  'IND',
#  'IDN',
#  'IRN',
#  'IRQ',
#  'IRL',
#  'ISR',
#  'ITA',
#  'CIV',
#  'JAM',
#  'JPN',
#  'JOR',
#  'KAZ',
#  'KEN',
#  'KHM',
#  'KOR',
#  'PRK',
#  'KWT',
#  'KGZ',
#  'LAO',
#  'LVA',
#  'LBN',
#  'LSO',
#  'LBR',
#  'LBY',
#  'LIE',
#  'LTU',
#  'LUX',
#  'MAC',
#  'MKD',
#  'MDG',
#  'MWI',
#  'MYS',
#  'MDV',
#  'MLI',
#  'MLT',
#  'MTQ',
#  'MRT',
#  'MUS',
#  'MEX',
#  'FSM',
#  'MCO',
#  'MNG',
#  'MNE',
#  'MSR',
#  'MAR',
#  'MOZ',
#  'MNP',
#  'NAM',
#  'NRU',
#  'NPL',
#  'NLD',
#  'CUW',
#  'ANT',
#  'SXM',
#  'NCL',
#  'VUT',
#  'NZL',
#  'NIC',
#  'NER',
#  'NGA',
#  'NIU',
#  'NFK',
#  'NOR',
#  'OMN',
#  'MHL',
#  'PAK',
#  'PSE',
#  'PAN',
#  'PNG',
#  'PRY',
#  'PER',
#  'PHL',
#  'PCN',
#  'POL',
#  'PRT',
#  'MDA',
#  'GNB',
#  'TLS',
#  'PRI',
#  'QAT',
#  'REU',
#  'ROU',
#  'RUS',
#  'RWA',
#  'BLM',
#  'SHN',
#  'KNA',
#  'LCA',
#  'MAF',
#  'SPM',
#  'VCT',
#  'SVK',
#  'SMR',
#  'SVN',
#  'STP',
#  'SAU',
#  'SEN',
#  'SRB',
#  'SYC',
#  'SLE',
#  'SGP',
#  'SOM',
#  'ZAF',
#  'ZWE',
#  'ESP',
#  'SSD',
#  'SDN',
#  'ESH',
#  'LKA',
#  'XDN',
#  'SUR',
#  'SJM',
#  'SWZ',
#  'SWE',
#  'CHE',
#  'SYR',
#  'TJK',
#  'TZA',
#  'THA',
#  'TGO',
#  'TKL',
#  'TON',
#  'TUV',
#  'TTO',
#  'TUN',
#  'TUR',
#  'TKM',
#  'TCA',
#  'UGA',
#  'BLR',
#  'UKR',
#  'ARE',
#  'GBR',
#  'ZZA',
#  'GGY',
#  'JEY',
#  'IMN',
#  'USA',
#  'BFA',
#  'URY',
#  'UZB',
#  'VEN',
#  'VNM',
#  'VGB',
#  'VIR',
#  'WLF',
#  'WSM',
#  'YEM',
#  'COD',
#  'ZMB']

# %%
# get the list of countries as country names
sdg.available_countries(as_names=True)
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Azerbaijan',
#  'Austria',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Belize',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia (Plurinational State of)',
#  'Botswana',
#  'Brazil',
#  'Solomon Islands',
#  'Palau',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Croatia',
#  'Myanmar',
#  'Burundi',
#  'Cameroon',
#  'Canada',
#  'Cabo Verde',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Mayotte',
#  'Congo',
#  'Cook Islands',
#  'Costa Rica',
#  'Cuba',
#  'Cyprus',
#  'Czechia',
#  'Benin',
#  'Denmark',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Faeroe Islands',
#  'Falkland Islands (Malvinas)',
#  'Fiji',
#  'Finland',
#  'Åland Islands',
#  'France',
#  'French Guiana',
#  'French Polynesia',
#  'Djibouti',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Kiribati',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Holy See',
#  'Honduras',
#  'China, Hong Kong Special Administrative Region',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran (Islamic Republic of)',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  "Côte d'Ivoire",
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Cambodia',
#  'Republic of Korea',
#  "Democratic People's Republic of Korea",
#  'Kuwait',
#  'Kyrgyzstan',
#  "Lao People's Democratic Republic",
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'China, Macao Special Administrative Region',
#  'North Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Martinique',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Micronesia (Federated States of)',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Mozambique',
#  'Northern Mariana Islands',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'Curaçao',
#  'Netherlands Antilles',
#  'Sint Maarten (Dutch part)',
#  'New Caledonia',
#  'Vanuatu',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Niue',
#  'Norfolk Island',
#  'Norway',
#  'Oman',
#  'Marshall Islands',
#  'Pakistan',
#  'Palestine',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Pitcairn',
#  'Poland',
#  'Portugal',
#  'Republic of Moldova',
#  'Guinea-Bissau',
#  'Timor-Leste',
#  'Puerto Rico',
#  'Qatar',
#  'Réunion',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Saint-Barthélemy',
#  'Saint Helena',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint-Martin (French part)',
#  'Saint Pierre and Miquelon',
#  'Saint Vincent and the Grenadines',
#  'Slovakia',
#  'San Marino',
#  'Slovenia',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Somalia',
#  'South Africa',
#  'Zimbabwe',
#  'Spain',
#  'South Sudan',
#  'Sudan',
#  'Western Sahara',
#  'Sri Lanka',
#  'Sudan (pre-secession)',
#  'Suriname',
#  'Svalbard and Jan Mayen Islands',
#  'Eswatini',
#  'Sweden',
#  'Switzerland',
#  'Syrian Arab Republic',
#  'Tajikistan',
#  'United Republic of Tanzania',
#  'Thailand',
#  'Togo',
#  'Tokelau',
#  'Tonga',
#  'Tuvalu',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Uganda',
#  'Belarus',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Channel Islands',
#  'Guernsey',
#  'Jersey',
#  'Isle of Man',
#  'United States of America',
#  'Burkina Faso',
#  'Uruguay',
#  'Uzbekistan',
#  'Venezuela (Bolivarian Republic of)',
#  'Viet Nam',
#  'British Virgin Islands',
#  'United States Virgin Islands',
#  'Wallis and Futuna Islands',
#  'Samoa',
#  'Yemen',
#  'Democratic Republic of the Congo',
#  'Zambia']

# %%
# You can also see which countries belong to a particular region
# here we will see which countries belong to the World Bank's country grouping for Small States
sdg.available_countries(as_names=True, region='WB: Small states')
# Out:
# ['Antigua and Barbuda',
#  'Bahamas',
#  'Bahrain',
#  'Barbados',
#  'Belize',
#  'Bhutan',
#  'Botswana',
#  'Solomon Islands',
#  'Palau',
#  'Brunei Darussalam',
#  'Cabo Verde',
#  'Comoros',
#  'Cyprus',
#  'Dominica',
#  'Equatorial Guinea',
#  'Estonia',
#  'Fiji',
#  'Djibouti',
#  'Gabon',
#  'Gambia',
#  'Kiribati',
#  'Grenada',
#  'Guyana',
#  'Iceland',
#  'Jamaica',
#  'Lesotho',
#  'Maldives',
#  'Malta',
#  'Mauritius',
#  'Micronesia (Federated States of)',
#  'Montenegro',
#  'Namibia',
#  'Nauru',
#  'Vanuatu',
#  'Marshall Islands',
#  'Guinea-Bissau',
#  'Timor-Leste',
#  'Qatar',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Seychelles',
#  'Suriname',
#  'Eswatini',
#  'Tonga',
#  'Tuvalu',
#  'Trinidad and Tobago',
#  'Samoa']

# %%
# you can also see the regions that are available.
# Note that some datasets may not have regional data, so calling this function may raise an error explaining that regional data is not available
sdg.available_regions()
# Out:
# ['AIMS: Asia and the Pacific',
#  'AIMS: Central Asia',
#  'AIMS: East Asia',
#  'AIMS: East Asia and the Pacific',
#  'AIMS: Pacific',
#  'AIMS: South and West Asia',
#  'ALECSO: Gulf countries',
#  'ALECSO: Least developed countries',
#  'ALECSO: Maghreb countries',
#  'ALECSO: Mashriq countries',
#  'ALECSO: Member countries',
#  'CECC-SICA',
#  'ECA: African Union Commission (UNSDCode:98106)',
#  'ECA: All countries (UNSDCode:98100)',
#  'ECA: Central Africa (UNSDCode:98101)',
#  'ECA: East Africa (UNSDCode:98102)',
#  'ECA: North Africa (UNSDCode:98103)',
#  'ECA: Southern Africa (UNSDCode:98104)',
#  'ECA: West Africa (UNSDCode:98105)',
#  'ECE: All countries (UNSDCode:98200)',
#  'ECE: CIS (CWG) (UNSDCode:98201)',
#  'ECE: Eastern Europe, Caucasus and Central Asia (CIS) (UNSDCode:98202)',
#  'ECE: Euro area (E25) (UNSDCode:98204)',
#  'ECE: European Union (EMU) (UNSDCode:98203)',
#  'ECE: West Balkans (ST7) (UNSDCode:98205)',
#  'ECLAC: All countries (UNSDCode:98300)',
#  'ECLAC: Carribean (UNSDCode:98301)',
#  'ECLAC: Latin America (UNSDCode:98302)',
#  'ESCAP: ADB Developing member countries (ADB_DMC) (UNSDCode:98401)',
#  'ESCAP: ADB Group A (ADB_DMC_A) (UNSDCode:98402)',
#  'ESCAP: ADB Group B (ADB_DMC_B) (UNSDCode:98403)',
#  'ESCAP: ADB Group C (ADB_DMC_C) (UNSDCode:98404)',
#  'ESCAP: Africa (AFR) (UNSDCode:98405)',
#  'ESCAP: All countries (UNSDCode:98400)',
#  'ESCAP: ASEAN (ASEAN) (UNSDCode:98406)',
#  'ESCAP: East and North-East Asia (ENEA) (UNSDCode:98408)',
#  'ESCAP: ECO (ECO) (UNSDCode:98407)',
#  'ESCAP: ENEA including Russian Fed (ENEA_RUS) (UNSDCode:98433)',
#  'ESCAP: Europe (Europe) (UNSDCode:98423)',
#  'ESCAP: Latin America (LAC) (UNSDCode:98424)',
#  'ESCAP: LDC (LDC_E) (UNSDCode:98411)',
#  'ESCAP: LLDC (LLDC_E) (UNSDCode:98412)',
#  'ESCAP: North America (NAM) (UNSDCode:98425)',
#  'ESCAP: North and Central Asia (NCA) (UNSDCode:98417)',
#  'ESCAP: Other Area (OTH_REGION) (UNSDCode:98426)',
#  'ESCAP: PACIFIC (PAC) (UNSDCode:98418)',
#  'ESCAP: Pacific island developing economies (PIDE) (UNSDCode:98427)',
#  'ESCAP: SAARC (SAARC) (UNSDCode:98428)',
#  'ESCAP: South and South-West Asia (SSWA) (UNSDCode:98420)',
#  'ESCAP: South-East Asia (SEA) (UNSDCode:98419)',
#  'ESCWA: All countries (UNSDCode:98500)',
#  'ESCWA: Arab countries (UNSDCode:98501)',
#  'GPE: (February 2016)',
#  'GPE: Fragile or conflict-affected (FY16)',
#  'GPE: Fragile or Conflict-affected countries (FCAC) FY 20, June 2020',
#  'GPE: Non Fragile & non Conflict-affected countries (NON-FCAC) FY20, June 2020',
#  'GPE: Non-fragile and non-conflict-affected (FY16)',
#  'GPE: Overall FY20, all 68 countries, June 2020',
#  'MDG: Caribbean',
#  'MDG: Caucasus and Central Asia',
#  'MDG: Developed regions',
#  'MDG: Developing regions',
#  'MDG: Eastern Asia',
#  'MDG: Eastern Asia (excluding China)',
#  'MDG: Latin America',
#  'MDG: Latin America and the Caribbean',
#  'MDG: Northern Africa',
#  'MDG: Oceania',
#  'MDG: South-eastern Asia',
#  'MDG: Southern Asia',
#  'MDG: Southern Asia (excluding India)',
#  'MDG: Sub-Saharan Africa',
#  'MDG: Western Asia',
#  'MDG: World',
#  'SDG: Africa (Northern)',
#  'SDG: Africa (Sub-Saharan)',
#  'SDG: Asia (Central and Southern)',
#  'SDG: Asia (Central)',
#  'SDG: Asia (Eastern and South-eastern)',
#  'SDG: Asia (Eastern)',
#  'SDG: Asia (South-eastern)',
#  'SDG: Asia (Southern)',
#  'SDG: Asia (Western)',
#  'SDG: Europe',
#  'SDG: Landlocked Developing Countries',
#  'SDG: Latin America and the Caribbean',
#  'SDG: Least Developed Countries',
#  'SDG: Northern America',
#  'SDG: Northern America and Europe',
#  'SDG: Oceania',
#  'SDG: Oceania (Australia/New Zealand)',
#  'SDG: Oceania (excl. Australia/New Zealand)',
#  'SDG: Small Island Developing States',
#  'SDG: Western Asia and Northern Africa',
#  'SDG: World',
#  'UIS: Arab States',
#  'UIS: Central and Eastern Europe',
#  'UIS: Central Asia',
#  'UIS: East Asia and the Pacific',
#  'UIS: Latin America and the Caribbean',
#  'UIS: North America and Western Europe',
#  'UIS: South and West Asia',
#  'UIS: Sub-Saharan Africa',
#  'UIS: World',
#  'UNESCO: SIDS',
#  'UNICEF: Africa',
#  'UNICEF: All UNICEF Countries',
#  'UNICEF: Association of South East Asian Nations (ASEAN)',
#  'UNICEF: Central and Eastern Europe/Commonwealth of Independent States',
#  'UNICEF: East Asia and Pacific',
#  'UNICEF: East Asia and the Pacific Programme Countries',
#  'UNICEF: Eastern and Southern Africa',
#  'UNICEF: Eastern Europe and Central Asia',
#  'UNICEF: Economic Community of Central African States (ECCAS)',
#  'UNICEF: Economic Community of West African States (ECOWAS)',
#  'UNICEF: Europe and Central Asia',
#  'UNICEF: Europe and Central Asia Programme Countries',
#  'UNICEF: Gulf Area',
#  'UNICEF: Latin America and Caribbean',
#  'UNICEF: Middle East and North Africa',
#  'UNICEF: Middle East and North Africa Programme Countries',
#  'UNICEF: North America',
#  'UNICEF: South Asia',
#  'UNICEF: Sub-Saharan Africa',
#  'UNICEF: West and Central Africa',
#  'UNICEF: Western Balkans',
#  'UNICEF: Western Europe',
#  'UNICEF: World',
#  'WB: Arab World',
#  'WB: Caribbean small states',
#  'WB: Central Europe and the Baltics',
#  'WB: Early-demographic dividend',
#  'WB: East Asia & Pacific',
#  'WB: East Asia & Pacific (excluding high income)',
#  'WB: East Asia & Pacific (IDA & IBRD)',
#  'WB: Euro area',
#  'WB: Europe & Central Asia',
#  'WB: Europe & Central Asia (excluding high income)',
#  'WB: Europe & Central Asia (IDA & IBRD)',
#  'WB: European Union',
#  'WB: Fragile and conflict affected situations',
#  'WB: FY21 IDA & IBRD countries classified as fragile situation',
#  'WB: FY21 IDA & IBRD total',
#  'WB: FY21 IDA classified as fragile situation',
#  'WB: FY21 IDA total',
#  'WB: Global Partnership for Education (July 2019)',
#  'WB: Heavily Indebted Poor Countries (HIPC)',
#  'WB: High income (July 2021)',
#  'WB: IBRD only',
#  'WB: IDA & IBRD total',
#  'WB: IDA blend',
#  'WB: IDA only',
#  'WB: IDA total',
#  'WB: Late-demographic dividend',
#  'WB: Latin America & Caribbean',
#  'WB: Latin America & Caribbean (excluding high income)',
#  'WB: Latin America & Caribbean (IDA & IBRD)',
#  'WB: Least developed countries: UN classification',
#  'WB: Low & middle income (July 2021)',
#  'WB: Low income (July 2021)',
#  'WB: Lower middle income (July 2021)',
#  'WB: Middle East & North Africa',
#  'WB: Middle East & North Africa (excluding high income)',
#  'WB: Middle East & North Africa (IDA & IBRD)',
#  'WB: Middle income (July 2021)',
#  'WB: North America',
#  'WB: OECD members',
#  'WB: Other small states',
#  'WB: Pacific island small states',
#  'WB: Post-demographic dividend',
#  'WB: Pre-demographic dividend',
#  'WB: Small states',
#  'WB: South Asia',
#  'WB: South Asia (IDA & IBRD)',
#  'WB: Sub-Saharan Africa',
#  'WB: Sub-Saharan Africa (excluding high income)',
#  'WB: Sub-Saharan Africa (IDA & IBRD)',
#  'WB: Upper middle income (July 2021)',
#  'WB: World']

# %% [markdown]
# In order the get the data, use the `get_data()` method

# %%
sdg.get_data()
# Out:
#                   INDICATOR_ID  \
# 0       ADMI.ENDOFLOWERSEC.MAT
# 1       ADMI.ENDOFLOWERSEC.MAT
# 2       ADMI.ENDOFLOWERSEC.MAT
# 3       ADMI.ENDOFLOWERSEC.MAT
# 4       ADMI.ENDOFLOWERSEC.MAT
# ...                        ...
# 815058              XGDP.FSGOV
# 815059              XGDP.FSGOV
# 815060              XGDP.FSGOV
# 815061              XGDP.FSGOV
# 815062              XGDP.FSGOV
#
#                                            INDICATOR_NAME COUNTRY_ID  \
# 0        Administration of a nationally-representative...        ABW
# 1        Administration of a nationally-representative...        ABW
# 2        Administration of a nationally-representative...        ABW
# 3        Administration of a nationally-representative...        ABW
# 4        Administration of a nationally-representative...        ABW
# ...                                                   ...        ...
# 815058  Government expenditure on education as a perce...        JOR
# 815059  Government expenditure on education as a perce...        JOR
# 815060  Government expenditure on education as a perce...        PHL
# 815061  Government expenditure on education as a perce...        COD
# 815062  Government expenditure on education as a perce...        COD
#
#                             COUNTRY_NAME  YEAR  VALUE
# 0                                  Aruba  2014   0.00
# 1                                  Aruba  2015   0.00
# 2                                  Aruba  2016   0.00
# 3                                  Aruba  2017   0.00
# 4                                  Aruba  2018   0.00
# ...                                  ...   ...    ...
# 815058                            Jordan  2014   3.80
# 815059                            Jordan  2015   3.45
# 815060                       Philippines  2020   3.88
# 815061  Democratic Republic of the Congo  2020   2.45
# 815062  Democratic Republic of the Congo  2021   2.70
#
# [815063 rows x 6 columns]

# %%
# if you are interested in regional data, you can specify the grouping
sdg.get_data(grouping='regional')
# Out:
#        INDICATOR_ID                                     INDICATOR_NAME  \
# 0       AIR.1.GLAST  Gross intake ratio to the last grade of primar...
# 1       AIR.1.GLAST  Gross intake ratio to the last grade of primar...
# 2       AIR.1.GLAST  Gross intake ratio to the last grade of primar...
# 3       AIR.1.GLAST  Gross intake ratio to the last grade of primar...
# 4       AIR.1.GLAST  Gross intake ratio to the last grade of primar...
# ...             ...                                                ...
# 549167     TRTP.3.M  Proportion of teachers with the minimum requir...
# 549168     TRTP.3.M  Proportion of teachers with the minimum requir...
# 549169     TRTP.3.M  Proportion of teachers with the minimum requir...
# 549170     TRTP.3.M  Proportion of teachers with the minimum requir...
# 549171     TRTP.3.M  Proportion of teachers with the minimum requir...
#
#                                   REGION_ID  YEAR     VALUE
# 0                AIMS: Asia and the Pacific  1970  71.41793
# 1                AIMS: Asia and the Pacific  1971  71.43174
# 2                AIMS: Asia and the Pacific  1972  71.86948
# 3                AIMS: Asia and the Pacific  1973  72.56180
# 4                AIMS: Asia and the Pacific  1974  72.72099
# ...                                     ...   ...       ...
# 549167  WB: Sub-Saharan Africa (IDA & IBRD)  2019  64.29370
# 549168                            WB: World  2016  84.62772
# 549169                            WB: World  2017  85.16457
# 549170                            WB: World  2018  86.44261
# 549171                            WB: World  2019  79.39685
#
# [549172 rows x 5 columns]

# %%
# You can also include metadata in the outputted dataframe
sdg.get_data(include_metadata=True)
# Out:
#                   INDICATOR_ID COUNTRY_ID  YEAR  VALUE MAGNITUDE QUALIFIER  \
# 0       ADMI.ENDOFLOWERSEC.MAT        ABW  2014   0.00       NaN       NaN
# 1       ADMI.ENDOFLOWERSEC.MAT        ABW  2015   0.00       NaN       NaN
# 2       ADMI.ENDOFLOWERSEC.MAT        ABW  2016   0.00       NaN       NaN
# 3       ADMI.ENDOFLOWERSEC.MAT        ABW  2017   0.00       NaN       NaN
# 4       ADMI.ENDOFLOWERSEC.MAT        ABW  2018   0.00       NaN       NaN
# ...                        ...        ...   ...    ...       ...       ...
# 815058              XGDP.FSGOV        JOR  2014   3.80       NaN       NaN
# 815059              XGDP.FSGOV        JOR  2015   3.45       NaN       NaN
# 815060              XGDP.FSGOV        PHL  2020   3.88       NaN       NaN
# 815061              XGDP.FSGOV        COD  2020   2.45       NaN       NaN
# 815062              XGDP.FSGOV        COD  2021   2.70       NaN       NaN
#
#                             COUNTRY_NAME  \
# 0                                  Aruba
# 1                                  Aruba
# 2                                  Aruba
# 3                                  Aruba
# 4                                  Aruba
# ...                                  ...
# 815058                            Jordan
# 815059                            Jordan
# 815060                       Philippines
# 815061  Democratic Republic of the Congo
# 815062  Democratic Republic of the Congo
#
#                                            INDICATOR_NAME Different Coverage  \
# 0        Administration of a nationally-representative...                NaN
# 1        Administration of a nationally-representative...                NaN
# 2        Administration of a nationally-representative...                NaN
# 3        Administration of a nationally-representative...                NaN
# 4        Administration of a nationally-representative...                NaN
# ...                                                   ...                ...
# 815058  Government expenditure on education as a perce...                NaN
# 815059  Government expenditure on education as a perce...                NaN
# 815060  Government expenditure on education as a perce...                NaN
# 815061  Government expenditure on education as a perce...                NaN
# 815062  Government expenditure on education as a perce...                NaN
#
#                                                    Source Under Coverage
# 0                                                     NaN            NaN
# 1                                                     NaN            NaN
# 2                                                     NaN            NaN
# 3                                                     NaN            NaN
# 4                                                     NaN            NaN
# ...                                                   ...            ...
# 815058                                                IMF            NaN
# 815059                                                IMF            NaN
# 815060                                                IMF            NaN
# 815061  Type of data:Revised estimates / Budget;Source...            NaN
# 815062  "Engagements de contributions des pays" (Agree...            NaN
#
# [815063 rows x 11 columns]
